# %% [markdown]
# # Unstructured Model

# %%
import os
import copy
import torch
import pickle
import pprint
import random
import shutil
import random
import torch
import hashlib
import numpy as np
import pandas as pd
from rnn import RNN
import torch.nn as nn
from vocab import Vocab
from torch import optim
from util import *
from constants import *
from evaluator import Evaluator
from tqdm.notebook import tqdm
from sklearn.metrics import *
from transformers import AdamW
from collections import Counter
import torch.nn.functional as F
from collections import OrderedDict
from torch.autograd import Variable
from matplotlib import pyplot as plt
from sklearn.preprocessing import *
from embedding_layer import EmbeddingLayer
from attention_layer import AttentionLayer
from torch.nn.utils.rnn import pad_sequence
from gensim.models.word2vec import Word2Vec
from dataloaders import TextDataLoader, TextDataset
from gensim.models.keyedvectors import KeyedVectors
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
tqdm.pandas()

# %%
# !nvidia-smi
# Out:
# Fri Feb 17 14:26:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla M40 24GB      Off  | 00000000:04:00.0 Off |                    0 |
# | N/A   48C    P0    58W / 250W |  19371MiB / 22945MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla M40 24GB      Off  | 00000000:82:00.0 Off |                    0 |
# | N/A   44C    P0    59W / 250W |  13485MiB / 22945MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   2489168      C   -                                4025MiB |
# |    1   N/A  N/A   2489168      C   -                                3533MiB |
# +-----------------------------------------------------------------------------+

# %%
device
# Out:
# device(type='cuda', index=3)

# %%
def read_data(file_path) -> list:
    data = pd.read_csv(file_path, on_bad_lines='skip')
    id_data = data[id_col_name]
    text_data = data[text_col_name]
    hierarchical_label_data = []
    label_data = data[label_col_name].tolist()
    output = []
    for i in tqdm(range(len(label_data)), desc="Reading data"):
        labels = label_data[i].split(';')
        output.append((text_data[i], labels, id_data[i]))
    return output

# %%
def read_labeldesc(file_path) -> list:
    data = pd.read_csv(file_path)
    desc_data = data[desc_col_name].tolist()
    label_data = data[label_col_name].tolist()
    output = []
    for i in tqdm(range(len(label_data)), desc="Reading Label Descriptions"):
        output.append((label_data[i], desc_data[i]))
    return output

# %%
def load_cached_data(file_path: str) -> tuple:
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
        f.close()
    return data["vocab"], data["training_data"], data["valid_data"], data["test_data"],data["label_desc"]

# %%
def prepare_data():
    cache_folder = "{}/{}".format(cache_dir, "mimic3_single_50")
#     device_name = 'cuda' if torch.cuda.is_available() else 'cpu'
    save_vocab_file_name = "{}.pkl".format("save_vocab")
    cached_file_name = os.path.join(cache_folder, save_vocab_file_name)
    if os.path.exists(cached_file_name):
        vocab, training_data, valid_data, test_data, label_desc = load_cached_data(cached_file_name)
        data = training_data + valid_data + test_data
        labels = []
        for (feature, l, _) in data:
            labels.extend(l)
        unique_labels=list(set(labels))
        n_labels = len(unique_labels)
        labels = unique_labels
        vocab.update_labels(labels)
        print("Loaded vocab and data from file")
    else:
        training_data = read_data( data_dir + "/ensemble_train.csv")
        valid_data = read_data( data_dir + "/ensemble_dev.csv")
        test_data = read_data( data_dir + "/ensemble_test.csv")
        label_desc = read_labeldesc(data_dir + "/D_ICD_50_ensemble.csv")
        data = training_data + valid_data + test_data
        labels = []
        for (feature, l, _) in data:
            labels.extend(l)
        unique_labels=list(set(labels))
        n_labels = len(unique_labels)
        labels = unique_labels
        vocab = Vocab(data, labels,label_desc,min_word_frequency,
                          word_embedding_mode=embedding_mode,
                          word_embedding_file=embedding_file)
        print("Preparing the vocab")
        vocab.prepare_vocab()
        saved_objects = {"vocab": vocab,
                         "training_data": training_data,
                         "valid_data": valid_data,
                         "test_data": test_data,
                         "label_desc": label_desc}
        with open(cached_file_name, 'wb') as f:
            pickle.dump(saved_objects, f, pickle.HIGHEST_PROTOCOL)
            f.close()
        print("Saved vocab and data to files")
    return training_data, valid_data, test_data ,label_desc, vocab,cached_file_name

# %%
training_data, valid_data, test_data, label_desc, vocab, saved_vocab_path = prepare_data()
# Out:
# Loaded vocab and data from file

# %%
model = RNN(vocab, device)
model
# Out:
# RNN(
#   (embedding): EmbeddingLayer(
#     (embeddings): Embedding(66379, 100)
#   )
#   (label_linear): Linear(in_features=100, out_features=256, bias=True)
#   (rnn): LSTM(100, 256, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (attention): AttentionLayer(
#     (first_linear): Linear(in_features=512, out_features=256, bias=False)
#     (second_linear): Linear(in_features=256, out_features=50, bias=False)
#     (third_linear): Linear(in_features=512, out_features=256, bias=False)
#   )
#   (classification_layer): Linear(in_features=256, out_features=50, bias=True)
# )

# %%
class Trainer:
    def __init__(self, model: nn.Module,
                 train_dataloader: TextDataLoader,
                 valid_dataloader: TextDataLoader,
                 test_dataloader: TextDataLoader,
                 criterions,
                 optimiser,
                 scheduler,
                 vocab,
                 checkpoint_path,
                 ):
        self.model = model
        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.test_dataloader = test_dataloader
        self.criterions = criterions
        self.optimiser = optimiser
        self.scheduler = scheduler
        self.vocab = vocab
        self.multilabel = multilabel
        self.checkpoint_path = checkpoint_path
        self.n_training_labels = n_labels
        self.saved_result_path = '../model/results.pkl'
        self.main_metric = main_metric
        self.start_epoch = 0
        self.best_val = None
        self.saved_test_scores = None
        self.best_epoch_num = 1

    def train_single_epoch(self, index):
        self.model.train()
        self.train_dataloader.dataset.shuffle_data()
        losses = []
        true_labels = []
        pred_probs = []
        ids = []
        all_loss_list = []
        progress_bar = tqdm(self.train_dataloader, unit="batches", desc="Training at epoch #{}".format(index))
        progress_bar.clear()
        self.optimiser.zero_grad()
        batch_id = 0

        for text_batch, label_batch, length_batch, id_batch, desc_batch in progress_bar:
            batch_id += 1
            text_batch = text_batch.to(device)
            label_batch = label_batch.to(device)
            length_batch = length_batch.to(device)
            desc_batch = desc_batch.to(device)
            true_labels.extend(label_batch.cpu().numpy())
            ids.extend(id_batch)
            output = self.model(text_batch, length_batch,desc_batch)
            loss_list = []
            loss_list = self.criterions(output, label_batch)
            all_loss_list.append([loss_list.item()])
            output = torch.sigmoid(output)
            output = output.detach().cpu().numpy()
            pred_probs.extend(output)
            loss = get_loss(loss_list, self.n_training_labels)
            loss.backward()
            losses.append(loss.item())
            self.optimiser.step()
            self.optimiser.zero_grad()

        scores = OrderedDict()
        scores = calculate_eval_metrics(ids, true_labels,pred_probs, self.multilabel)
        scores["loss"] = np.mean(all_loss_list).item()
        scores["average"] = np.mean(losses).item()
        progress_bar.refresh(True)
        progress_bar.clear(True)
        progress_bar.close()
        keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1', 'macro_P@5', 'macro_P@8', 'macro_P@15', 'loss']
        print({k:v for k,v in scores.items() if k in keys})
        return scores


    @staticmethod
    def format_number(number):
        return abs(round(number, ndigits=ndigits))

    def train(self,n_epoch: int = 100):
        best_valid_scores = self.best_val
        saved_test_scores = self.saved_test_scores
        saved_train_scores = None
        best_epoch_num = self.best_epoch_num
        evaluator = Evaluator(self.model, self.vocab, self.criterions, self.n_training_labels, device)
        for e in range(self.start_epoch + 1, n_epoch + 1):
            train_scores = self.train_single_epoch(e)
            epoch_loss = train_scores["average"]
            valid_scores = evaluator.evaluate(self.valid_dataloader)
            test_scores = evaluator.evaluate(self.test_dataloader)
            self.scheduler.step(test_scores["average"])
            print('lr {}'.format(self.optimiser.param_groups[0]['lr']))
            keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1', 'macro_P@5', 'macro_P@8', 'macro_P@15', 'loss']
            print({k:v for k,v in test_scores.items() if k in keys})
            print('\n\n')
            
            if best_valid_scores is None or best_valid_scores[self.main_metric] < valid_scores[self.main_metric]:
                best_valid_scores = valid_scores
                saved_test_scores = test_scores
                saved_train_scores = train_scores
                best_epoch_num = e
                

                    
        results = {"train": saved_train_scores, "valid": best_valid_scores, "test": saved_test_scores,
                    "index2label": self.vocab.index2label}
        with open(self.saved_result_path, 'wb') as f:
            pickle.dump(results, f, pickle.HIGHEST_PROTOCOL)
                
        return self.model, best_valid_scores

# %%
def _load_and_cache_data(train_data, valid_data, test_data, label_desc, vocab, saved_data_file_path):
    if os.path.exists(saved_data_file_path):
        try:
            with open(saved_data_file_path, 'rb') as f:
                data = pickle.load(f)
                data["train"].multilabel = bool(multilabel)
                data["valid"].multilabel = bool(multilabel)
                data["test"].multilabel = bool(multilabel)

                return data["train"], data["valid"], data["test"]
        except:
            pass

    # Build train/valid/test data loaders
    train_dataset = TextDataset(train_data, vocab, label_desc,max_seq_length=max_seq_length,min_seq_length=min_seq_length,sort=True,multilabel=multilabel)

    valid_dataset = TextDataset(valid_data, vocab, label_desc,max_seq_length=max_seq_length,min_seq_length=min_seq_length,sort=True,multilabel=multilabel)

    test_dataset = TextDataset(test_data, vocab, label_desc,max_seq_length=max_seq_length,min_seq_length=min_seq_length,sort=True, multilabel=multilabel)
    
    # try:
    with open(saved_data_file_path, 'wb') as f:
        data = {"train": train_dataset, "valid": valid_dataset, "test": test_dataset}
        pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
    
    return train_dataset, valid_dataset, test_dataset

# %%
def _train_model(train_data, valid_data, test_data, label_desc, vocab, saved_data_file_path=None,checkpoint_path=None):
    model = RNN(vocab,device)
    init_state_dict = None
    if init_state_dict is not None:
        model.load_state_dict(init_state_dict)
    model.to(device)

    train_dataset, valid_dataset, test_dataset = _load_and_cache_data(train_data, valid_data, test_data, label_desc,
                                                                      vocab, saved_data_file_path)
    
    train_dataloader = TextDataLoader(dataset=train_dataset, vocab=vocab, batch_size=batch_size)

    valid_dataloader = TextDataLoader(dataset=valid_dataset, vocab=vocab, batch_size=batch_size)

    test_dataloader = TextDataLoader(dataset=test_dataset, vocab=vocab, batch_size=batch_size)

    optimiser = torch.optim.AdamW(model.parameters(), lr = 0.001)
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser, 'min', patience=1)
    
    criterions = nn.BCEWithLogitsLoss(pos_weight = torch.tensor(2))

    trainer = Trainer(model=model,
                      train_dataloader=train_dataloader,
                      valid_dataloader=valid_dataloader,
                      test_dataloader=test_dataloader,
                      criterions=criterions,
                      optimiser=optimiser,
                      scheduler = scheduler,
                      vocab=vocab,
                      checkpoint_path=checkpoint_path)
    best_model, scores = trainer.train(n_epoch=n_epoch)

    evaluator = Evaluator(model=best_model,vocab=vocab,criterions=criterions,
                          n_training_labels=n_labels,device = device)

    del model, optimiser, evaluator, trainer, criterions
    return best_model, scores  # either on valid or test

# %%
def run_with_validation(training_data, valid_data, test_data, label_desc, vocab, saved_data_file_path):
    best_model, scores = _train_model(
        train_data=training_data, valid_data=valid_data, test_data=test_data, label_desc=label_desc,
        vocab=vocab, saved_data_file_path=saved_data_file_path, checkpoint_path="../model/checkpoint.pkl")

    return best_model, scores

# %%
# best_model, scores = run_with_validation(training_data, valid_data, test_data, label_desc, vocab, saved_data_file_path="{}.data.pkl".format(saved_vocab_path.split(".pkl")[0]))
# Out:
# Training at epoch #1:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.18565896114123714, 'macro_auc': 0.5930879067057798, 'macro_P@5': 0.38314870762000675, 'macro_P@8': 0.32917925478348437, 'macro_P@15': 0.26489873559359967, 'micro_f1': 0.3187177397446346, 'micro_auc': 0.7132445992917851, 'loss': 0.5788818134906444}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.28265958593318785, 'macro_auc': 0.7277355632209351, 'macro_P@5': 0.44597364568081993, 'macro_P@8': 0.38872620790629575, 'macro_P@15': 0.3031722791605661, 'micro_f1': 0.41491889658022524, 'micro_auc': 0.7734177856208493, 'loss': 0.550098875706846}
# Training at epoch #2:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.3128542465632952, 'macro_auc': 0.7476717974532237, 'macro_P@5': 0.5115139308492783, 'macro_P@8': 0.43420610943269555, 'macro_P@15': 0.3223676849054492, 'micro_f1': 0.47209332809018223, 'micro_auc': 0.8254132823553413, 'loss': 0.4760574593823007}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.4022373865696165, 'macro_auc': 0.7918386683202463, 'macro_P@5': 0.5382137628111274, 'macro_P@8': 0.4560761346998536, 'macro_P@15': 0.33821376281112736, 'micro_f1': 0.4854763355677432, 'micro_auc': 0.8250975848763229, 'loss': 0.49664695290001953}
# Training at epoch #3:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.40920643176855137, 'macro_auc': 0.8080304038777755, 'macro_P@5': 0.5735481705270224, 'macro_P@8': 0.48409701242027525, 'macro_P@15': 0.35195255678639364, 'micro_f1': 0.5407684865924144, 'micro_auc': 0.8686313743688825, 'loss': 0.4244151714634388}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.4745470773344905, 'macro_auc': 0.8385943910273316, 'macro_P@5': 0.6038067349926793, 'macro_P@8': 0.5159224011713031, 'macro_P@15': 0.3783308931185944, 'micro_f1': 0.5604071246819339, 'micro_auc': 0.8743796398808154, 'loss': 0.4423462436957793}
# Training at epoch #4:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.49619736866868525, 'macro_auc': 0.8478389241099944, 'macro_P@5': 0.6268546492111448, 'macro_P@8': 0.5250923128566634, 'macro_P@15': 0.3763007720711648, 'micro_f1': 0.6026474242569052, 'micro_auc': 0.897615036182218, 'loss': 0.3830216301882521}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.5638864176682739, 'macro_auc': 0.8680891560108575, 'macro_P@5': 0.659736456808199, 'macro_P@8': 0.5560029282576867, 'macro_P@15': 0.39824304538799415, 'micro_f1': 0.6267098632109431, 'micro_auc': 0.8970686474026102, 'loss': 0.40465902062979614}
# Training at epoch #5:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.5560917679244135, 'macro_auc': 0.8775913081658746, 'macro_P@5': 0.6610943269553542, 'macro_P@8': 0.55702416918429, 'macro_P@15': 0.39221215172876805, 'micro_f1': 0.643756253053817, 'micro_auc': 0.9175913995537751, 'loss': 0.34740499391200697}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.6176277842678811, 'macro_auc': 0.883458999552581, 'macro_P@5': 0.6822840409956076, 'macro_P@8': 0.58400439238653, 'macro_P@15': 0.41259150805270867, 'micro_f1': 0.6547826086956522, 'micro_auc': 0.9148362101530518, 'loss': 0.374733565883203}
# Training at epoch #6:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.5986694771551813, 'macro_auc': 0.8955027075247416, 'macro_P@5': 0.6819738167170191, 'macro_P@8': 0.5743538100033568, 'macro_P@15': 0.4032225579053374, 'micro_f1': 0.6684317440029215, 'micro_auc': 0.9286531207514317, 'loss': 0.3263277959950427}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.6323234373819416, 'macro_auc': 0.8932950081913, 'macro_P@5': 0.696632503660322, 'macro_P@8': 0.5940702781844802, 'macro_P@15': 0.41669106881405565, 'micro_f1': 0.6660333362121081, 'micro_auc': 0.91969986644192, 'loss': 0.36446009982715954}
# Training at epoch #7:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.6297732056368707, 'macro_auc': 0.9087355313170074, 'macro_P@5': 0.6987579724739846, 'macro_P@8': 0.5888301443437395, 'macro_P@15': 0.40953340046995634, 'micro_f1': 0.6865244359621021, 'micro_auc': 0.9367125512784984, 'loss': 0.30859553116433164}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.6353695958721518, 'macro_auc': 0.8968452190781672, 'macro_P@5': 0.6986822840409955, 'macro_P@8': 0.592606149341142, 'macro_P@15': 0.41913128355295265, 'micro_f1': 0.676114081996435, 'micro_auc': 0.9211710534962247, 'loss': 0.3644143315878781}
# Training at epoch #8:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.6425534573082069, 'macro_auc': 0.9154978113154499, 'macro_P@5': 0.708291372943941, 'macro_P@8': 0.5964249748237663, 'macro_P@15': 0.4127559583752937, 'micro_f1': 0.6961543688001087, 'micro_auc': 0.941424288996588, 'loss': 0.29779821967190884}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.6440852966295447, 'macro_auc': 0.8965063797517101, 'macro_P@5': 0.7048316251830161, 'macro_P@8': 0.5957174231332357, 'macro_P@15': 0.42088823816495846, 'micro_f1': 0.6750715307582261, 'micro_auc': 0.9227825569961405, 'loss': 0.36149173974990845}
# Training at epoch #9:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.6569456037163456, 'macro_auc': 0.9215227759850877, 'macro_P@5': 0.7201074185968446, 'macro_P@8': 0.6049848942598187, 'macro_P@15': 0.417343627615531, 'micro_f1': 0.7079909706546276, 'micro_auc': 0.9456688817062827, 'loss': 0.2881580049053152}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.001
# {'macro_f1': 0.6344678030636162, 'macro_auc': 0.8967520731415358, 'macro_P@5': 0.6945827232796485, 'macro_P@8': 0.5913250366032211, 'macro_P@15': 0.41825280624694977, 'micro_f1': 0.6690986742592757, 'micro_auc': 0.9212144379082289, 'loss': 0.3633069084449248}
# Training at epoch #10:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.6710635546008673, 'macro_auc': 0.9262960574608424, 'macro_P@5': 0.72715676401477, 'macro_P@8': 0.6123699227928835, 'macro_P@15': 0.4199619559136175, 'micro_f1': 0.7188990079320242, 'micro_auc': 0.9494110385385854, 'loss': 0.2778643864266416}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.0001
# {'macro_f1': 0.6420574789094662, 'macro_auc': 0.8970305706270553, 'macro_P@5': 0.6998535871156661, 'macro_P@8': 0.5944363103953147, 'macro_P@15': 0.4200097608589556, 'micro_f1': 0.6793043158185331, 'micro_auc': 0.9215449616914865, 'loss': 0.37365932491692627}
# Training at epoch #11:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.7125850930890711, 'macro_auc': 0.9400574983373708, 'macro_P@5': 0.7530715005035247, 'macro_P@8': 0.6317556226921786, 'macro_P@15': 0.4279064563052479, 'micro_f1': 0.7465116279069768, 'micro_auc': 0.9587253561180759, 'loss': 0.25329087896549957}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 0.0001
# {'macro_f1': 0.6594923007833325, 'macro_auc': 0.897682648170408, 'macro_P@5': 0.7045387994143484, 'macro_P@8': 0.6023060029282576, 'macro_P@15': 0.42264519277696433, 'micro_f1': 0.6888646288209606, 'micro_auc': 0.9245915677869095, 'loss': 0.36406617679379205}
# Training at epoch #12:   0%|          | 0/94 [00:00<?, ?batches/s]
# {'macro_f1': 0.7179826673757999, 'macro_auc': 0.9429731778653588, 'macro_P@5': 0.75730110775428, 'macro_P@8': 0.6362873447465592, 'macro_P@15': 0.42985341837305585, 'micro_f1': 0.752857077812685, 'micro_auc': 0.9609479882199459, 'loss': 0.24545037556201854}
# Evaluating:   0%|          | 0/19 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# lr 1e-05
# {'macro_f1': 0.6616873925354992, 'macro_auc': 0.8975336876379281, 'macro_P@5': 0.7080527086383602, 'macro_P@8': 0.6024890190336749, 'macro_P@15': 0.423718887262079, 'micro_f1': 0.6892964686558993, 'micro_auc': 0.9249033689797274, 'loss': 0.36536121232943103}

# %%
torch.save(obj = best_model.state_dict(), f = '../model/cdlaat50_for_ensemble.pth')

# %%
loaded_model = RNN(vocab, device)

# %%
loaded_model.load_state_dict(state_dict = torch.load(f = '../model/cdlaat50_for_ensemble.pth', map_location={'cuda:3':'cuda:1'}))
# Out:
# <All keys matched successfully>

# %%
loaded_model.to(device)
# Out:
# RNN(
#   (embedding): EmbeddingLayer(
#     (embeddings): Embedding(66379, 100)
#   )
#   (label_linear): Linear(in_features=100, out_features=256, bias=True)
#   (rnn): LSTM(100, 256, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (attention): AttentionLayer(
#     (first_linear): Linear(in_features=512, out_features=256, bias=False)
#     (second_linear): Linear(in_features=256, out_features=50, bias=False)
#     (third_linear): Linear(in_features=512, out_features=256, bias=False)
#   )
#   (classification_layer): Linear(in_features=256, out_features=50, bias=True)
# )

# %%
train_dataset, valid_dataset, test_dataset = _load_and_cache_data(training_data, valid_data, test_data, label_desc,
                                                                      vocab, '{}.testdata.pkl')


test_dataloader = TextDataLoader(dataset = test_dataset, vocab = vocab, batch_size = 32)
train_dataloader = TextDataLoader(dataset = train_dataset, vocab = vocab, batch_size = 32)

criterions = nn.BCEWithLogitsLoss(pos_weight = torch.tensor(2))
evaluator = Evaluator(model = loaded_model, vocab = vocab, criterions = criterions,
                          n_training_labels = 50, device = device)

test_scores = evaluator.evaluate(test_dataloader)
train_scores = evaluator.evaluate(train_dataloader)
# Out:
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]
# Evaluating:   0%|          | 0/94 [00:00<?, ?batches/s]

# %%
train_scores['pred_probs'] = np.array(train_scores['pred_probs'])
train_scores['true_labels'] = np.array(train_scores['true_labels'])
train_scores['true_labels'].shape
# Out:
# (2979, 50)

# %%
test_scores['pred_probs'] = np.array(test_scores['pred_probs'])
test_scores['true_labels'] = np.array(test_scores['true_labels'])
test_scores['true_labels'].shape
# Out:
# (683, 50)

# %%
# Sorting outputs according to increasing hadm ids
# print(np.array(test_scores['true_labels']))
test_scores['hadm_ids'] = np.array(test_scores['hadm_ids'])
sort = np.argsort(test_scores['hadm_ids'])
test_scores['hadm_ids'] = test_scores['hadm_ids'][sort]
test_scores['true_labels'] = test_scores['true_labels'][sort]
test_scores['pred_probs'] = test_scores['pred_probs'][sort]
# print(test_scores['true_labels'])

# %%
train_scores['hadm_ids'] = np.array(train_scores['hadm_ids'])
sort = np.argsort(train_scores['hadm_ids'])
train_scores['hadm_ids'] = train_scores['hadm_ids'][sort]
train_scores['true_labels'] = train_scores['true_labels'][sort]
train_scores['pred_probs'] = train_scores['pred_probs'][sort]

# %%
train_scores['true_labels'].shape
# Out:
# (2979, 50)

# %%
# df = pd.read_csv('../data/dev.csv')
# train_ids_df = pd.read_csv('../../Structured/dev_final.csv')
# train_ids = list(train_ids_df['HADM_ID'])
# len(train_ids)
# train_ensemble = df.loc[df['HADM_ID'].isin(train_ids)]
# train_ensemble.to_csv('../data/ensemble_dev.csv', index = False)

# %% [markdown]
# # Strcutured Data Pre-processing

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.datasets import make_classification
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, jaccard_score

from sklearn.datasets import make_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle
import numpy as np

# %%
icd9 = ['401.9','38.93','428.0','427.31','414.01','96.04','96.6','584.9','250.00','96.71','272.4','518.81','99.04','39.61','599.0','530.81','96.72','272.0','285.9','88.56','244.9','486','38.91','285.1','36.15','276.2','496','99.15',
 '995.92','V58.61','507.0','038.9','88.72','585.9', '403.90','311','305.1','37.22','412','33.24','39.95','287.5','410.71','276.1','V45.81','424.0','45.13','V15.82','511.9','37.23']

# %%
icd9.sort()

# %%
# test_df = pd.read_csv('../../Structured/train_final.csv')
# test_df = test_df.sort_values('HADM_ID')

# df = pd.read_csv('../data/ensemble_train.csv')
# df = df.sort_values('HADM_ID')
# df.to_csv('../data/ensemble_train.csv', index = False)

# test_df['ICD9_CODE'] = df['ICD9_CODE'].values

# test_df.to_csv('../../Structured/train_final.csv', index = False)

# %%
train_df = pd.read_csv('../../Structured/train_final.csv')
train_dataset = train_df.to_dict('records')

test_df = pd.read_csv('../../Structured/test_final.csv')
test_dataset = test_df.to_dict('records')

dev_df = pd.read_csv('../../Structured/dev_final.csv')
dev_dataset = dev_df.to_dict('records')

# %%
def generate_dataset(dataset):
# convert df icd9_codes column into one hot vector
    for row in dataset:
        labels = [0] * 50
        codes = list(row['ICD9_CODE'].split(";"))
        for i in range(len(codes)):
            labels[icd9.index(codes[i])] = 1
        row['ICD9_CODE'] = labels

        # get list of features (lab events item ids) 
        keys = dataset[0].keys()
        keys = list(keys)
        keys.remove('SUBJECT_ID')
        keys.remove('HADM_ID')
        keys.remove('ICD9_CODE')

    # Create dataset from df feature values
    X = []
    y = []
    for row in dataset:
        x = []
        for key in keys:
            x.append(row[key])
        X.append(x)
        y.append(row['ICD9_CODE'])
    return X, y

# %%
X_train, y_train = generate_dataset(train_dataset)
X_test, y_test = generate_dataset(test_dataset)
X_train = np.array(X_train)
y_test = np.array(y_test)
y_train = np.array(y_train)
X_test = np.array(X_test)

# %% [markdown]
# # Random Forest Model for Structured data

# %%
forest = RandomForestClassifier(random_state=1, verbose = True)
multi_target_forest = MultiOutputClassifier(forest, n_jobs = 50)
multi_target_forest.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(random_state=1,
#                                                        verbose=True),
#                       n_jobs=50)

# %%
y_pred = multi_target_forest.predict_proba(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
y_pred = np.array(y_pred)
struct_input = y_pred[:, :, 1]
struct_input = struct_input.T
test_samples = y_test

# %%
final_test_input = np.hstack((struct_input, test_scores['pred_probs']))
final_test_input.shape
# Out:
# (683, 100)

# %%
unstruct_input = train_scores['pred_probs']

# %%
(test_samples == train_scores['true_labels']).all()
# Out:
# True

# %%
struct_input
# Out:
# array([[0.01, 0.04, 0.08, ..., 0.01, 0.02, 0.08],
#        [0.  , 0.  , 0.04, ..., 0.  , 0.  , 0.  ],
#        [0.03, 0.02, 0.06, ..., 0.03, 0.01, 0.  ],
#        ...,
#        [0.03, 0.03, 0.03, ..., 0.03, 0.02, 0.04],
#        [0.  , 0.  , 0.76, ..., 0.  , 0.  , 0.03],
#        [0.01, 0.01, 0.05, ..., 0.  , 0.  , 0.01]])

# %%
unstruct_input
# Out:
# array([[8.0290833e-04, 1.6817228e-03, 1.3759212e-03, ..., 2.3620503e-01,
#         4.3566674e-03, 4.1043884e-01],
#        [7.1197998e-04, 8.9640263e-05, 7.4339262e-03, ..., 1.3850629e-02,
#         3.9397500e-04, 3.4766892e-01],
#        [2.6855327e-02, 1.0729377e-03, 2.3872625e-02, ..., 1.9770779e-02,
#         7.1604300e-05, 7.7696680e-04],
#        ...,
#        [1.2498708e-03, 3.6024011e-04, 1.3787952e-03, ..., 7.8072414e-02,
#         1.0956029e-04, 1.0746276e-03],
#        [4.1244528e-04, 1.5686272e-03, 9.9283445e-01, ..., 2.0190965e-02,
#         4.0989107e-04, 1.7688164e-03],
#        [3.9203241e-03, 1.2049948e-04, 6.1907331e-03, ..., 3.2847994e-03,
#         4.5919098e-04, 6.5519131e-04]], dtype=float32)

# %% [markdown]
# # Basic Ensemble Model with linear weighing of models

# %%
mi_auc = []
ma_auc = []
mi_f1 = []
ma_f1 = []

for alpha in np.arange(0.0, 1.0, 0.001):
    final_output = struct_input * alpha + unstruct_input * (1 - alpha)
    scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test, final_output, True)
    keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
    print('aplha: ', alpha)
    print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
    mi_auc.append(scores['micro_auc'])
    ma_auc.append(scores['macro_auc'])
    mi_f1.append(scores['micro_f1'])
    ma_f1.append(scores['macro_f1'])
    print('\n')
# Out:
# aplha:  0.0
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.002
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.003
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.004
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.005
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.006
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.925'}
#
#
# aplha:  0.007
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.925'}
#
#
# aplha:  0.008
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.009000000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.926'}
#
#
# aplha:  0.01
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.011
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.012
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.013000000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.014
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.015
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.016
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.017
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.018000000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.019
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.02
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.021
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.022
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.023
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.024
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.025
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.026000000000000002
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.027
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.028
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.029
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.03
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.031
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.032
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.033
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.034
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.926'}
#
#
# aplha:  0.035
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.036000000000000004
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.037
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.038
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.039
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.04
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.041
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.042
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.043000000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.044
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.045
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.046
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.047
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.048
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.049
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.05
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.051000000000000004
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.052000000000000005
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.053
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.054
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.055
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.056
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.057
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.058
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.059000000000000004
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.06
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.061
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.062
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.063
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.064
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.065
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.066
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.067
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.068
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.069
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.07
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.07100000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.07200000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.073
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.074
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.075
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.076
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.077
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.078
# {'macro_f1': '0.660', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.079
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.928'}
# aplha:  0.08
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.081
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.082
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.083
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.084
# {'macro_f1': '0.661', 'macro_auc': '0.899', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.085
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.08600000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.08700000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.088
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.089
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.09
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.091
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.092
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.093
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.094
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.095
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.096
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.097
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.098
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.099
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.1
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.101
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.10200000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.692', 'micro_auc': '0.928'}
#
#
# aplha:  0.10300000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.692', 'micro_auc': '0.928'}
#
#
# aplha:  0.10400000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.105
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.106
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.107
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.108
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.109
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.11
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.111
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.112
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.113
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.114
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.115
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.116
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.117
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.11800000000000001
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.11900000000000001
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.12
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.121
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.122
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.123
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.124
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.125
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.126
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.127
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.128
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.129
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.13
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.131
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.132
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.133
# {'macro_f1': '0.659', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.134
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.135
# {'macro_f1': '0.660', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.136
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.137
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.138
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.139
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.14
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.14100000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.14200000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.14300000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.14400000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.145
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.146
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.147
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.148
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.149
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.15
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.151
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.152
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.153
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.154
# {'macro_f1': '0.663', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.155
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.156
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.157
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.158
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.159
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
# aplha:  0.16
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.161
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.162
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.163
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.164
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.165
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.166
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.167
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.168
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.169
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.17
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.171
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.17200000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.17300000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.17400000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.17500000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.176
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.177
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.178
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.179
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.18
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.181
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.182
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.183
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.184
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.185
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.186
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.187
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.188
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.189
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.19
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.191
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.192
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.193
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.194
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.195
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.196
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.197
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.198
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.199
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.2
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.201
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.202
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.203
# {'macro_f1': '0.659', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.928'}
#
#
# aplha:  0.20400000000000001
# {'macro_f1': '0.658', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.20500000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.20600000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.20700000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.20800000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.209
# {'macro_f1': '0.658', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.21
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.211
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.212
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.213
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.214
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.215
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.216
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.217
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.218
# {'macro_f1': '0.657', 'macro_auc': '0.901', 'micro_f1': '0.690', 'micro_auc': '0.929'}
#
#
# aplha:  0.219
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.22
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.221
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.222
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.223
# {'macro_f1': '0.655', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.224
# {'macro_f1': '0.655', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.225
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.226
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.227
# {'macro_f1': '0.656', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.228
# {'macro_f1': '0.655', 'macro_auc': '0.901', 'micro_f1': '0.689', 'micro_auc': '0.929'}
#
#
# aplha:  0.229
# {'macro_f1': '0.655', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.23
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.231
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.232
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.233
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.234
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.23500000000000001
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.23600000000000002
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.23700000000000002
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.23800000000000002
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.23900000000000002
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
# aplha:  0.24
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.241
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.242
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.243
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.244
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.929'}
#
#
# aplha:  0.245
# {'macro_f1': '0.654', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.246
# {'macro_f1': '0.643', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.247
# {'macro_f1': '0.642', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.248
# {'macro_f1': '0.642', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.249
# {'macro_f1': '0.642', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.25
# {'macro_f1': '0.642', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.251
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.252
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.688', 'micro_auc': '0.928'}
#
#
# aplha:  0.253
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.254
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.255
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.256
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.257
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.258
# {'macro_f1': '0.641', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.259
# {'macro_f1': '0.640', 'macro_auc': '0.901', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.26
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.261
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.687', 'micro_auc': '0.928'}
#
#
# aplha:  0.262
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.263
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.264
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.265
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.266
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.267
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.268
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.269
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.27
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.271
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.272
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.273
# {'macro_f1': '0.640', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.274
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.275
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.276
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.277
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.278
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.279
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28
# {'macro_f1': '0.639', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.281
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28200000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28300000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28400000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28500000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28600000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28700000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.28800000000000003
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.289
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.29
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.291
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.292
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.293
# {'macro_f1': '0.638', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.294
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.295
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.296
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.297
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.298
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.299
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.3
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.301
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.302
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.303
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.304
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.305
# {'macro_f1': '0.637', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.306
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.307
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.308
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.309
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.31
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.311
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.312
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.313
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.314
# {'macro_f1': '0.636', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.315
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.316
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.317
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.318
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.319
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
# aplha:  0.32
# {'macro_f1': '0.635', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.321
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.322
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.323
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.324
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.325
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.326
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.327
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.328
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.329
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.33
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.331
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.332
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.333
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.334
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.335
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.336
# {'macro_f1': '0.634', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.337
# {'macro_f1': '0.633', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.338
# {'macro_f1': '0.633', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.339
# {'macro_f1': '0.633', 'macro_auc': '0.902', 'micro_f1': '0.686', 'micro_auc': '0.928'}
#
#
# aplha:  0.34
# {'macro_f1': '0.633', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.341
# {'macro_f1': '0.633', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.342
# {'macro_f1': '0.632', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.343
# {'macro_f1': '0.632', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.34400000000000003
# {'macro_f1': '0.632', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.34500000000000003
# {'macro_f1': '0.632', 'macro_auc': '0.902', 'micro_f1': '0.685', 'micro_auc': '0.928'}
#
#
# aplha:  0.34600000000000003
# {'macro_f1': '0.632', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.34700000000000003
# {'macro_f1': '0.632', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.34800000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.34900000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.35000000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.35100000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.352
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.353
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.354
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.355
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.356
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.357
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.358
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.359
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.36
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.361
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.683', 'micro_auc': '0.928'}
#
#
# aplha:  0.362
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.363
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.364
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.683', 'micro_auc': '0.928'}
#
#
# aplha:  0.365
# {'macro_f1': '0.631', 'macro_auc': '0.902', 'micro_f1': '0.684', 'micro_auc': '0.928'}
#
#
# aplha:  0.366
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.683', 'micro_auc': '0.928'}
#
#
# aplha:  0.367
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.683', 'micro_auc': '0.928'}
#
#
# aplha:  0.368
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.683', 'micro_auc': '0.928'}
#
#
# aplha:  0.369
# {'macro_f1': '0.630', 'macro_auc': '0.902', 'micro_f1': '0.683', 'micro_auc': '0.928'}
#
#
# aplha:  0.37
# {'macro_f1': '0.629', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.371
# {'macro_f1': '0.629', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.372
# {'macro_f1': '0.629', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.373
# {'macro_f1': '0.628', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.374
# {'macro_f1': '0.628', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.375
# {'macro_f1': '0.628', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.376
# {'macro_f1': '0.628', 'macro_auc': '0.902', 'micro_f1': '0.682', 'micro_auc': '0.928'}
#
#
# aplha:  0.377
# {'macro_f1': '0.627', 'macro_auc': '0.902', 'micro_f1': '0.681', 'micro_auc': '0.928'}
#
#
# aplha:  0.378
# {'macro_f1': '0.626', 'macro_auc': '0.902', 'micro_f1': '0.681', 'micro_auc': '0.928'}
#
#
# aplha:  0.379
# {'macro_f1': '0.626', 'macro_auc': '0.902', 'micro_f1': '0.681', 'micro_auc': '0.928'}
#
#
# aplha:  0.38
# {'macro_f1': '0.626', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.928'}
#
#
# aplha:  0.381
# {'macro_f1': '0.625', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.928'}
#
#
# aplha:  0.382
# {'macro_f1': '0.625', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.928'}
#
#
# aplha:  0.383
# {'macro_f1': '0.625', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.928'}
#
#
# aplha:  0.384
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.928'}
#
#
# aplha:  0.385
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.386
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.387
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.388
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.389
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.39
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.391
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.928'}
#
#
# aplha:  0.392
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.393
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.394
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.395
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.396
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.928'}
#
#
# aplha:  0.397
# {'macro_f1': '0.624', 'macro_auc': '0.902', 'micro_f1': '0.680', 'micro_auc': '0.927'}
#
#
# aplha:  0.398
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.399
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
# aplha:  0.4
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.401
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.402
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.403
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.404
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.405
# {'macro_f1': '0.623', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.406
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.40700000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.40800000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.40900000000000003
# {'macro_f1': '0.621', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.41000000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.41100000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.41200000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.41300000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.41400000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.902', 'micro_f1': '0.679', 'micro_auc': '0.927'}
#
#
# aplha:  0.41500000000000004
# {'macro_f1': '0.621', 'macro_auc': '0.902', 'micro_f1': '0.678', 'micro_auc': '0.927'}
#
#
# aplha:  0.41600000000000004
# {'macro_f1': '0.621', 'macro_auc': '0.902', 'micro_f1': '0.678', 'micro_auc': '0.927'}
#
#
# aplha:  0.417
# {'macro_f1': '0.620', 'macro_auc': '0.902', 'micro_f1': '0.677', 'micro_auc': '0.927'}
#
#
# aplha:  0.418
# {'macro_f1': '0.619', 'macro_auc': '0.902', 'micro_f1': '0.677', 'micro_auc': '0.927'}
#
#
# aplha:  0.419
# {'macro_f1': '0.619', 'macro_auc': '0.902', 'micro_f1': '0.677', 'micro_auc': '0.927'}
#
#
# aplha:  0.42
# {'macro_f1': '0.618', 'macro_auc': '0.902', 'micro_f1': '0.677', 'micro_auc': '0.927'}
#
#
# aplha:  0.421
# {'macro_f1': '0.616', 'macro_auc': '0.902', 'micro_f1': '0.676', 'micro_auc': '0.927'}
#
#
# aplha:  0.422
# {'macro_f1': '0.617', 'macro_auc': '0.902', 'micro_f1': '0.676', 'micro_auc': '0.927'}
#
#
# aplha:  0.423
# {'macro_f1': '0.616', 'macro_auc': '0.902', 'micro_f1': '0.675', 'micro_auc': '0.927'}
#
#
# aplha:  0.424
# {'macro_f1': '0.615', 'macro_auc': '0.902', 'micro_f1': '0.675', 'micro_auc': '0.927'}
#
#
# aplha:  0.425
# {'macro_f1': '0.615', 'macro_auc': '0.902', 'micro_f1': '0.675', 'micro_auc': '0.927'}
#
#
# aplha:  0.426
# {'macro_f1': '0.615', 'macro_auc': '0.902', 'micro_f1': '0.675', 'micro_auc': '0.927'}
#
#
# aplha:  0.427
# {'macro_f1': '0.615', 'macro_auc': '0.902', 'micro_f1': '0.675', 'micro_auc': '0.927'}
#
#
# aplha:  0.428
# {'macro_f1': '0.614', 'macro_auc': '0.902', 'micro_f1': '0.675', 'micro_auc': '0.927'}
#
#
# aplha:  0.429
# {'macro_f1': '0.614', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.43
# {'macro_f1': '0.614', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.431
# {'macro_f1': '0.614', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.432
# {'macro_f1': '0.613', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.433
# {'macro_f1': '0.613', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.434
# {'macro_f1': '0.614', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.435
# {'macro_f1': '0.613', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.436
# {'macro_f1': '0.613', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.437
# {'macro_f1': '0.613', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.438
# {'macro_f1': '0.612', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.439
# {'macro_f1': '0.612', 'macro_auc': '0.902', 'micro_f1': '0.674', 'micro_auc': '0.927'}
#
#
# aplha:  0.44
# {'macro_f1': '0.611', 'macro_auc': '0.902', 'micro_f1': '0.673', 'micro_auc': '0.927'}
#
#
# aplha:  0.441
# {'macro_f1': '0.612', 'macro_auc': '0.902', 'micro_f1': '0.673', 'micro_auc': '0.927'}
#
#
# aplha:  0.442
# {'macro_f1': '0.611', 'macro_auc': '0.902', 'micro_f1': '0.673', 'micro_auc': '0.927'}
#
#
# aplha:  0.443
# {'macro_f1': '0.611', 'macro_auc': '0.902', 'micro_f1': '0.673', 'micro_auc': '0.927'}
#
#
# aplha:  0.444
# {'macro_f1': '0.611', 'macro_auc': '0.902', 'micro_f1': '0.672', 'micro_auc': '0.927'}
#
#
# aplha:  0.445
# {'macro_f1': '0.610', 'macro_auc': '0.902', 'micro_f1': '0.672', 'micro_auc': '0.927'}
#
#
# aplha:  0.446
# {'macro_f1': '0.609', 'macro_auc': '0.902', 'micro_f1': '0.671', 'micro_auc': '0.927'}
#
#
# aplha:  0.447
# {'macro_f1': '0.609', 'macro_auc': '0.902', 'micro_f1': '0.672', 'micro_auc': '0.927'}
#
#
# aplha:  0.448
# {'macro_f1': '0.609', 'macro_auc': '0.902', 'micro_f1': '0.671', 'micro_auc': '0.927'}
#
#
# aplha:  0.449
# {'macro_f1': '0.609', 'macro_auc': '0.902', 'micro_f1': '0.671', 'micro_auc': '0.927'}
#
#
# aplha:  0.45
# {'macro_f1': '0.609', 'macro_auc': '0.902', 'micro_f1': '0.671', 'micro_auc': '0.927'}
#
#
# aplha:  0.451
# {'macro_f1': '0.608', 'macro_auc': '0.902', 'micro_f1': '0.670', 'micro_auc': '0.927'}
#
#
# aplha:  0.452
# {'macro_f1': '0.608', 'macro_auc': '0.902', 'micro_f1': '0.670', 'micro_auc': '0.927'}
#
#
# aplha:  0.453
# {'macro_f1': '0.607', 'macro_auc': '0.902', 'micro_f1': '0.670', 'micro_auc': '0.927'}
#
#
# aplha:  0.454
# {'macro_f1': '0.607', 'macro_auc': '0.902', 'micro_f1': '0.670', 'micro_auc': '0.927'}
#
#
# aplha:  0.455
# {'macro_f1': '0.608', 'macro_auc': '0.902', 'micro_f1': '0.670', 'micro_auc': '0.927'}
#
#
# aplha:  0.456
# {'macro_f1': '0.607', 'macro_auc': '0.902', 'micro_f1': '0.669', 'micro_auc': '0.927'}
#
#
# aplha:  0.457
# {'macro_f1': '0.607', 'macro_auc': '0.902', 'micro_f1': '0.669', 'micro_auc': '0.927'}
#
#
# aplha:  0.458
# ...
#
#
# aplha:  0.848
# {'macro_f1': '0.239', 'macro_auc': '0.878', 'micro_f1': '0.367', 'micro_auc': '0.894'}
#
#
# aplha:  0.849
# {'macro_f1': '0.239', 'macro_auc': '0.878', 'micro_f1': '0.366', 'micro_auc': '0.894'}
#
#
# aplha:  0.85
# {'macro_f1': '0.238', 'macro_auc': '0.877', 'micro_f1': '0.365', 'micro_auc': '0.894'}
#
#
# aplha:  0.851
# {'macro_f1': '0.238', 'macro_auc': '0.877', 'micro_f1': '0.364', 'micro_auc': '0.894'}
#
#
# aplha:  0.852
# {'macro_f1': '0.237', 'macro_auc': '0.877', 'micro_f1': '0.363', 'micro_auc': '0.893'}
#
#
# aplha:  0.853
# {'macro_f1': '0.237', 'macro_auc': '0.876', 'micro_f1': '0.363', 'micro_auc': '0.893'}
#
#
# aplha:  0.854
# {'macro_f1': '0.237', 'macro_auc': '0.876', 'micro_f1': '0.362', 'micro_auc': '0.893'}
#
#
# aplha:  0.855
# {'macro_f1': '0.237', 'macro_auc': '0.876', 'micro_f1': '0.362', 'micro_auc': '0.893'}
#
#
# aplha:  0.856
# {'macro_f1': '0.238', 'macro_auc': '0.876', 'micro_f1': '0.362', 'micro_auc': '0.892'}
#
#
# aplha:  0.857
# {'macro_f1': '0.237', 'macro_auc': '0.875', 'micro_f1': '0.360', 'micro_auc': '0.892'}
#
#
# aplha:  0.858
# {'macro_f1': '0.237', 'macro_auc': '0.875', 'micro_f1': '0.359', 'micro_auc': '0.892'}
#
#
# aplha:  0.859
# {'macro_f1': '0.237', 'macro_auc': '0.875', 'micro_f1': '0.359', 'micro_auc': '0.891'}
#
#
# aplha:  0.86
# {'macro_f1': '0.235', 'macro_auc': '0.874', 'micro_f1': '0.356', 'micro_auc': '0.891'}
#
#
# aplha:  0.861
# {'macro_f1': '0.234', 'macro_auc': '0.874', 'micro_f1': '0.354', 'micro_auc': '0.891'}
#
#
# aplha:  0.862
# {'macro_f1': '0.233', 'macro_auc': '0.874', 'micro_f1': '0.354', 'micro_auc': '0.891'}
#
#
# aplha:  0.863
# {'macro_f1': '0.233', 'macro_auc': '0.873', 'micro_f1': '0.353', 'micro_auc': '0.890'}
#
#
# aplha:  0.864
# {'macro_f1': '0.233', 'macro_auc': '0.873', 'micro_f1': '0.353', 'micro_auc': '0.890'}
#
#
# aplha:  0.865
# {'macro_f1': '0.233', 'macro_auc': '0.873', 'micro_f1': '0.353', 'micro_auc': '0.890'}
#
#
# aplha:  0.866
# {'macro_f1': '0.233', 'macro_auc': '0.872', 'micro_f1': '0.352', 'micro_auc': '0.889'}
#
#
# aplha:  0.867
# {'macro_f1': '0.233', 'macro_auc': '0.872', 'micro_f1': '0.352', 'micro_auc': '0.889'}
#
#
# aplha:  0.868
# {'macro_f1': '0.233', 'macro_auc': '0.872', 'micro_f1': '0.351', 'micro_auc': '0.889'}
#
#
# aplha:  0.869
# {'macro_f1': '0.233', 'macro_auc': '0.871', 'micro_f1': '0.351', 'micro_auc': '0.888'}
#
#
# aplha:  0.87
# {'macro_f1': '0.232', 'macro_auc': '0.871', 'micro_f1': '0.350', 'micro_auc': '0.888'}
#
#
# aplha:  0.871
# {'macro_f1': '0.232', 'macro_auc': '0.871', 'micro_f1': '0.349', 'micro_auc': '0.888'}
#
#
# aplha:  0.872
# {'macro_f1': '0.232', 'macro_auc': '0.870', 'micro_f1': '0.349', 'micro_auc': '0.888'}
#
#
# aplha:  0.873
# {'macro_f1': '0.231', 'macro_auc': '0.870', 'micro_f1': '0.347', 'micro_auc': '0.887'}
#
#
# aplha:  0.874
# {'macro_f1': '0.230', 'macro_auc': '0.870', 'micro_f1': '0.346', 'micro_auc': '0.887'}
#
#
# aplha:  0.875
# {'macro_f1': '0.230', 'macro_auc': '0.869', 'micro_f1': '0.346', 'micro_auc': '0.887'}
#
#
# aplha:  0.876
# {'macro_f1': '0.230', 'macro_auc': '0.869', 'micro_f1': '0.344', 'micro_auc': '0.886'}
#
#
# aplha:  0.877
# {'macro_f1': '0.228', 'macro_auc': '0.868', 'micro_f1': '0.344', 'micro_auc': '0.886'}
# aplha:  0.878
# {'macro_f1': '0.227', 'macro_auc': '0.868', 'micro_f1': '0.343', 'micro_auc': '0.886'}
#
#
# aplha:  0.879
# {'macro_f1': '0.227', 'macro_auc': '0.868', 'micro_f1': '0.342', 'micro_auc': '0.885'}
#
#
# aplha:  0.88
# {'macro_f1': '0.227', 'macro_auc': '0.867', 'micro_f1': '0.341', 'micro_auc': '0.885'}
#
#
# aplha:  0.881
# {'macro_f1': '0.227', 'macro_auc': '0.867', 'micro_f1': '0.341', 'micro_auc': '0.885'}
#
#
# aplha:  0.882
# {'macro_f1': '0.226', 'macro_auc': '0.866', 'micro_f1': '0.340', 'micro_auc': '0.884'}
#
#
# aplha:  0.883
# {'macro_f1': '0.226', 'macro_auc': '0.866', 'micro_f1': '0.339', 'micro_auc': '0.884'}
#
#
# aplha:  0.884
# {'macro_f1': '0.226', 'macro_auc': '0.866', 'micro_f1': '0.339', 'micro_auc': '0.884'}
#
#
# aplha:  0.885
# {'macro_f1': '0.225', 'macro_auc': '0.865', 'micro_f1': '0.338', 'micro_auc': '0.883'}
#
#
# aplha:  0.886
# {'macro_f1': '0.226', 'macro_auc': '0.865', 'micro_f1': '0.338', 'micro_auc': '0.883'}
#
#
# aplha:  0.887
# {'macro_f1': '0.225', 'macro_auc': '0.864', 'micro_f1': '0.337', 'micro_auc': '0.883'}
#
#
# aplha:  0.888
# {'macro_f1': '0.225', 'macro_auc': '0.864', 'micro_f1': '0.337', 'micro_auc': '0.882'}
#
#
# aplha:  0.889
# {'macro_f1': '0.224', 'macro_auc': '0.863', 'micro_f1': '0.336', 'micro_auc': '0.882'}
#
#
# aplha:  0.89
# {'macro_f1': '0.223', 'macro_auc': '0.863', 'micro_f1': '0.334', 'micro_auc': '0.882'}
#
#
# aplha:  0.891
# {'macro_f1': '0.223', 'macro_auc': '0.862', 'micro_f1': '0.333', 'micro_auc': '0.881'}
#
#
# aplha:  0.892
# {'macro_f1': '0.222', 'macro_auc': '0.862', 'micro_f1': '0.331', 'micro_auc': '0.881'}
#
#
# aplha:  0.893
# {'macro_f1': '0.221', 'macro_auc': '0.861', 'micro_f1': '0.330', 'micro_auc': '0.881'}
#
#
# aplha:  0.894
# {'macro_f1': '0.221', 'macro_auc': '0.861', 'micro_f1': '0.330', 'micro_auc': '0.880'}
#
#
# aplha:  0.895
# {'macro_f1': '0.221', 'macro_auc': '0.861', 'micro_f1': '0.330', 'micro_auc': '0.880'}
#
#
# aplha:  0.896
# {'macro_f1': '0.221', 'macro_auc': '0.860', 'micro_f1': '0.329', 'micro_auc': '0.880'}
#
#
# aplha:  0.897
# {'macro_f1': '0.221', 'macro_auc': '0.860', 'micro_f1': '0.330', 'micro_auc': '0.879'}
#
#
# aplha:  0.898
# {'macro_f1': '0.221', 'macro_auc': '0.859', 'micro_f1': '0.329', 'micro_auc': '0.879'}
#
#
# aplha:  0.899
# {'macro_f1': '0.221', 'macro_auc': '0.859', 'micro_f1': '0.329', 'micro_auc': '0.878'}
#
#
# aplha:  0.9
# {'macro_f1': '0.221', 'macro_auc': '0.858', 'micro_f1': '0.329', 'micro_auc': '0.878'}
#
#
# aplha:  0.901
# {'macro_f1': '0.220', 'macro_auc': '0.858', 'micro_f1': '0.328', 'micro_auc': '0.878'}
#
#
# aplha:  0.902
# {'macro_f1': '0.220', 'macro_auc': '0.857', 'micro_f1': '0.328', 'micro_auc': '0.877'}
#
#
# aplha:  0.903
# {'macro_f1': '0.219', 'macro_auc': '0.857', 'micro_f1': '0.326', 'micro_auc': '0.877'}
#
#
# aplha:  0.904
# {'macro_f1': '0.218', 'macro_auc': '0.856', 'micro_f1': '0.323', 'micro_auc': '0.877'}
#
#
# aplha:  0.905
# {'macro_f1': '0.217', 'macro_auc': '0.855', 'micro_f1': '0.322', 'micro_auc': '0.876'}
#
#
# aplha:  0.906
# {'macro_f1': '0.217', 'macro_auc': '0.855', 'micro_f1': '0.322', 'micro_auc': '0.876'}
#
#
# aplha:  0.907
# {'macro_f1': '0.217', 'macro_auc': '0.854', 'micro_f1': '0.321', 'micro_auc': '0.875'}
#
#
# aplha:  0.908
# {'macro_f1': '0.217', 'macro_auc': '0.854', 'micro_f1': '0.321', 'micro_auc': '0.875'}
#
#
# aplha:  0.909
# {'macro_f1': '0.216', 'macro_auc': '0.853', 'micro_f1': '0.320', 'micro_auc': '0.875'}
#
#
# aplha:  0.91
# {'macro_f1': '0.215', 'macro_auc': '0.853', 'micro_f1': '0.319', 'micro_auc': '0.874'}
#
#
# aplha:  0.911
# {'macro_f1': '0.215', 'macro_auc': '0.852', 'micro_f1': '0.319', 'micro_auc': '0.874'}
#
#
# aplha:  0.912
# {'macro_f1': '0.215', 'macro_auc': '0.852', 'micro_f1': '0.318', 'micro_auc': '0.873'}
#
#
# aplha:  0.913
# {'macro_f1': '0.215', 'macro_auc': '0.851', 'micro_f1': '0.318', 'micro_auc': '0.873'}
#
#
# aplha:  0.914
# {'macro_f1': '0.215', 'macro_auc': '0.850', 'micro_f1': '0.318', 'micro_auc': '0.873'}
#
#
# aplha:  0.915
# {'macro_f1': '0.215', 'macro_auc': '0.850', 'micro_f1': '0.318', 'micro_auc': '0.872'}
#
#
# aplha:  0.916
# {'macro_f1': '0.215', 'macro_auc': '0.849', 'micro_f1': '0.317', 'micro_auc': '0.872'}
#
#
# aplha:  0.917
# {'macro_f1': '0.215', 'macro_auc': '0.848', 'micro_f1': '0.317', 'micro_auc': '0.871'}
#
#
# aplha:  0.918
# {'macro_f1': '0.214', 'macro_auc': '0.848', 'micro_f1': '0.317', 'micro_auc': '0.871'}
#
#
# aplha:  0.919
# {'macro_f1': '0.214', 'macro_auc': '0.847', 'micro_f1': '0.317', 'micro_auc': '0.870'}
#
#
# aplha:  0.92
# {'macro_f1': '0.214', 'macro_auc': '0.847', 'micro_f1': '0.317', 'micro_auc': '0.870'}
#
#
# aplha:  0.921
# {'macro_f1': '0.214', 'macro_auc': '0.846', 'micro_f1': '0.316', 'micro_auc': '0.870'}
#
#
# aplha:  0.922
# {'macro_f1': '0.214', 'macro_auc': '0.846', 'micro_f1': '0.315', 'micro_auc': '0.869'}
#
#
# aplha:  0.923
# {'macro_f1': '0.214', 'macro_auc': '0.845', 'micro_f1': '0.314', 'micro_auc': '0.869'}
#
#
# aplha:  0.924
# {'macro_f1': '0.213', 'macro_auc': '0.844', 'micro_f1': '0.313', 'micro_auc': '0.868'}
#
#
# aplha:  0.925
# {'macro_f1': '0.212', 'macro_auc': '0.844', 'micro_f1': '0.311', 'micro_auc': '0.868'}
#
#
# aplha:  0.926
# {'macro_f1': '0.211', 'macro_auc': '0.843', 'micro_f1': '0.310', 'micro_auc': '0.867'}
#
#
# aplha:  0.927
# {'macro_f1': '0.211', 'macro_auc': '0.842', 'micro_f1': '0.310', 'micro_auc': '0.867'}
#
#
# aplha:  0.928
# {'macro_f1': '0.210', 'macro_auc': '0.842', 'micro_f1': '0.310', 'micro_auc': '0.867'}
#
#
# aplha:  0.929
# {'macro_f1': '0.210', 'macro_auc': '0.841', 'micro_f1': '0.310', 'micro_auc': '0.866'}
#
#
# aplha:  0.93
# {'macro_f1': '0.210', 'macro_auc': '0.840', 'micro_f1': '0.310', 'micro_auc': '0.866'}
#
#
# aplha:  0.931
# {'macro_f1': '0.210', 'macro_auc': '0.840', 'micro_f1': '0.310', 'micro_auc': '0.865'}
#
#
# aplha:  0.932
# {'macro_f1': '0.210', 'macro_auc': '0.839', 'micro_f1': '0.310', 'micro_auc': '0.865'}
#
#
# aplha:  0.933
# {'macro_f1': '0.210', 'macro_auc': '0.838', 'micro_f1': '0.310', 'micro_auc': '0.864'}
#
#
# aplha:  0.934
# {'macro_f1': '0.210', 'macro_auc': '0.837', 'micro_f1': '0.309', 'micro_auc': '0.864'}
#
#
# aplha:  0.935
# {'macro_f1': '0.210', 'macro_auc': '0.836', 'micro_f1': '0.309', 'micro_auc': '0.863'}
#
#
# aplha:  0.936
# {'macro_f1': '0.210', 'macro_auc': '0.836', 'micro_f1': '0.308', 'micro_auc': '0.863'}
#
#
# aplha:  0.937
# {'macro_f1': '0.209', 'macro_auc': '0.835', 'micro_f1': '0.307', 'micro_auc': '0.862'}
#
#
# aplha:  0.9380000000000001
# {'macro_f1': '0.209', 'macro_auc': '0.834', 'micro_f1': '0.307', 'micro_auc': '0.862'}
#
#
# aplha:  0.9390000000000001
# {'macro_f1': '0.209', 'macro_auc': '0.834', 'micro_f1': '0.307', 'micro_auc': '0.861'}
#
#
# aplha:  0.9400000000000001
# {'macro_f1': '0.209', 'macro_auc': '0.833', 'micro_f1': '0.306', 'micro_auc': '0.861'}
#
#
# aplha:  0.9410000000000001
# {'macro_f1': '0.208', 'macro_auc': '0.832', 'micro_f1': '0.305', 'micro_auc': '0.860'}
#
#
# aplha:  0.9420000000000001
# {'macro_f1': '0.207', 'macro_auc': '0.831', 'micro_f1': '0.303', 'micro_auc': '0.860'}
#
#
# aplha:  0.9430000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.830', 'micro_f1': '0.303', 'micro_auc': '0.859'}
#
#
# aplha:  0.9440000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.829', 'micro_f1': '0.303', 'micro_auc': '0.859'}
#
#
# aplha:  0.9450000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.829', 'micro_f1': '0.303', 'micro_auc': '0.858'}
#
#
# aplha:  0.9460000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.828', 'micro_f1': '0.303', 'micro_auc': '0.858'}
#
#
# aplha:  0.9470000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.827', 'micro_f1': '0.303', 'micro_auc': '0.858'}
#
#
# aplha:  0.9480000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.827', 'micro_f1': '0.302', 'micro_auc': '0.857'}
#
#
# aplha:  0.9490000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.826', 'micro_f1': '0.302', 'micro_auc': '0.857'}
#
#
# aplha:  0.9500000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.825', 'micro_f1': '0.302', 'micro_auc': '0.856'}
#
#
# aplha:  0.9510000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.824', 'micro_f1': '0.302', 'micro_auc': '0.855'}
#
#
# aplha:  0.9520000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.822', 'micro_f1': '0.302', 'micro_auc': '0.855'}
#
#
# aplha:  0.9530000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.822', 'micro_f1': '0.301', 'micro_auc': '0.854'}
#
#
# aplha:  0.9540000000000001
# {'macro_f1': '0.206', 'macro_auc': '0.821', 'micro_f1': '0.301', 'micro_auc': '0.854'}
#
#
# aplha:  0.9550000000000001
# {'macro_f1': '0.205', 'macro_auc': '0.820', 'micro_f1': '0.300', 'micro_auc': '0.853'}
#
#
# aplha:  0.9560000000000001
# {'macro_f1': '0.205', 'macro_auc': '0.819', 'micro_f1': '0.300', 'micro_auc': '0.853'}
#
#
# aplha:  0.9570000000000001
# {'macro_f1': '0.205', 'macro_auc': '0.818', 'micro_f1': '0.298', 'micro_auc': '0.852'}
# aplha:  0.9580000000000001
# {'macro_f1': '0.204', 'macro_auc': '0.818', 'micro_f1': '0.298', 'micro_auc': '0.852'}
#
#
# aplha:  0.9590000000000001
# {'macro_f1': '0.204', 'macro_auc': '0.816', 'micro_f1': '0.296', 'micro_auc': '0.851'}
#
#
# aplha:  0.96
# {'macro_f1': '0.203', 'macro_auc': '0.815', 'micro_f1': '0.294', 'micro_auc': '0.851'}
#
#
# aplha:  0.961
# {'macro_f1': '0.201', 'macro_auc': '0.814', 'micro_f1': '0.292', 'micro_auc': '0.850'}
#
#
# aplha:  0.962
# {'macro_f1': '0.199', 'macro_auc': '0.813', 'micro_f1': '0.290', 'micro_auc': '0.849'}
#
#
# aplha:  0.963
# {'macro_f1': '0.199', 'macro_auc': '0.812', 'micro_f1': '0.290', 'micro_auc': '0.849'}
#
#
# aplha:  0.964
# {'macro_f1': '0.199', 'macro_auc': '0.812', 'micro_f1': '0.290', 'micro_auc': '0.849'}
#
#
# aplha:  0.965
# {'macro_f1': '0.199', 'macro_auc': '0.811', 'micro_f1': '0.290', 'micro_auc': '0.848'}
#
#
# aplha:  0.966
# {'macro_f1': '0.199', 'macro_auc': '0.810', 'micro_f1': '0.290', 'micro_auc': '0.848'}
#
#
# aplha:  0.967
# {'macro_f1': '0.199', 'macro_auc': '0.809', 'micro_f1': '0.290', 'micro_auc': '0.847'}
#
#
# aplha:  0.968
# {'macro_f1': '0.199', 'macro_auc': '0.808', 'micro_f1': '0.290', 'micro_auc': '0.846'}
#
#
# aplha:  0.969
# {'macro_f1': '0.199', 'macro_auc': '0.806', 'micro_f1': '0.290', 'micro_auc': '0.846'}
#
#
# aplha:  0.97
# {'macro_f1': '0.198', 'macro_auc': '0.805', 'micro_f1': '0.289', 'micro_auc': '0.845'}
#
#
# aplha:  0.971
# {'macro_f1': '0.198', 'macro_auc': '0.803', 'micro_f1': '0.289', 'micro_auc': '0.844'}
#
#
# aplha:  0.972
# {'macro_f1': '0.198', 'macro_auc': '0.803', 'micro_f1': '0.289', 'micro_auc': '0.844'}
#
#
# aplha:  0.973
# {'macro_f1': '0.198', 'macro_auc': '0.802', 'micro_f1': '0.288', 'micro_auc': '0.843'}
#
#
# aplha:  0.974
# {'macro_f1': '0.198', 'macro_auc': '0.802', 'micro_f1': '0.288', 'micro_auc': '0.843'}
#
#
# aplha:  0.975
# {'macro_f1': '0.198', 'macro_auc': '0.801', 'micro_f1': '0.288', 'micro_auc': '0.843'}
#
#
# aplha:  0.976
# {'macro_f1': '0.198', 'macro_auc': '0.800', 'micro_f1': '0.288', 'micro_auc': '0.842'}
#
#
# aplha:  0.977
# {'macro_f1': '0.197', 'macro_auc': '0.799', 'micro_f1': '0.287', 'micro_auc': '0.841'}
#
#
# aplha:  0.978
# {'macro_f1': '0.197', 'macro_auc': '0.797', 'micro_f1': '0.286', 'micro_auc': '0.841'}
#
#
# aplha:  0.979
# {'macro_f1': '0.197', 'macro_auc': '0.795', 'micro_f1': '0.286', 'micro_auc': '0.840'}
#
#
# aplha:  0.98
# {'macro_f1': '0.195', 'macro_auc': '0.793', 'micro_f1': '0.282', 'micro_auc': '0.839'}
#
#
# aplha:  0.981
# {'macro_f1': '0.194', 'macro_auc': '0.792', 'micro_f1': '0.280', 'micro_auc': '0.838'}
#
#
# aplha:  0.982
# {'macro_f1': '0.194', 'macro_auc': '0.792', 'micro_f1': '0.280', 'micro_auc': '0.838'}
#
#
# aplha:  0.983
# {'macro_f1': '0.194', 'macro_auc': '0.791', 'micro_f1': '0.280', 'micro_auc': '0.838'}
#
#
# aplha:  0.984
# {'macro_f1': '0.194', 'macro_auc': '0.791', 'micro_f1': '0.280', 'micro_auc': '0.837'}
#
#
# aplha:  0.985
# {'macro_f1': '0.194', 'macro_auc': '0.790', 'micro_f1': '0.280', 'micro_auc': '0.837'}
#
#
# aplha:  0.986
# {'macro_f1': '0.194', 'macro_auc': '0.789', 'micro_f1': '0.280', 'micro_auc': '0.836'}
#
#
# aplha:  0.987
# {'macro_f1': '0.194', 'macro_auc': '0.788', 'micro_f1': '0.280', 'micro_auc': '0.836'}
#
#
# aplha:  0.988
# {'macro_f1': '0.194', 'macro_auc': '0.786', 'micro_f1': '0.280', 'micro_auc': '0.835'}
#
#
# aplha:  0.989
# {'macro_f1': '0.194', 'macro_auc': '0.783', 'micro_f1': '0.280', 'micro_auc': '0.834'}
#
#
# aplha:  0.99
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.832'}
#
#
# aplha:  0.991
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.992
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.993
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.994
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.995
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.996
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.997
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.998
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}
#
#
# aplha:  0.999
# {'macro_f1': '0.194', 'macro_auc': '0.779', 'micro_f1': '0.280', 'micro_auc': '0.831'}

# %%
alphas = np.arange(0, 1, 0.001)
mi_auc = np.array(mi_auc)
ma_auc = np.array(ma_auc)
mi_f1 = np.array(mi_f1)
ma_f1 = np.array(ma_f1)

# %%
y = mi_auc
plt.plot(alphas, y)
ymax = max(y)
xpos = np.where(y == ymax)
xmax = alphas[xpos]

plt.grid()
plt.show()

print('Max value: ', ymax, ', at alpha = ', xmax)
# Out:
# Max value:  0.9285134490765563 , at alpha =  [0.222]
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    5.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.2s finished

# %%
summ = np.add(mi_auc, ma_auc)
summ = np.add(summ, mi_f1)
summ = np.add(summ, ma_f1)

# %%
pos = np.where(summ == max(summ))
print('pos:', pos)
print('alpha:', alphas[pos])
# Out:
# pos: (array([175]),)
# alpha: [0.175]

# %%
print('micro_auc:', mi_auc[pos])
print('macro_auc:', ma_auc[pos])
print('micro-f1:', mi_f1[pos])
print('macro-f1:', ma_f1[pos])
# Out:
# micro_auc: [0.92841197]
# macro_auc: [0.9007975]
# micro-f1: [0.69095336]
# macro-f1: [0.66248558]

# %% [markdown]
# # Training Structured Data on neural network

# %%
train_df = pd.read_csv('../../Structured/train_final.csv')
train_dataset = train_df.to_dict('records')

test_df = pd.read_csv('../../Structured/test_final.csv')
test_dataset = test_df.to_dict('records')

dev_df = pd.read_csv('../../Structured/dev_final.csv')
dev_dataset = dev_df.to_dict('records')

# %%
def generate_dataset(dataset):
# convert df icd9_codes column into one hot vector
    for row in dataset:
        labels = [0] * 50
        codes = list(row['ICD9_CODE'].split(";"))
        for i in range(len(codes)):
            labels[icd9.index(codes[i])] = 1
        row['ICD9_CODE'] = labels

        # get list of features (lab events item ids) 
        keys = dataset[0].keys()
        keys = list(keys)
        keys.remove('SUBJECT_ID')
        keys.remove('HADM_ID')
        keys.remove('ICD9_CODE')

    # Create dataset from df feature values
    X = []
    y = []
    for row in dataset:
        x = []
        for key in keys:
            x.append(row[key])
        X.append(x)
        y.append(row['ICD9_CODE'])
    return X, y

# %%
X_train, y_train = generate_dataset(train_dataset)
X_test, y_test = generate_dataset(test_dataset)
X_train = np.array(X_train)
y_test = np.array(y_test)
y_train = np.array(y_train)
X_test = np.array(X_test)

# %%
X_train = torch.from_numpy(X_train)
y_train = torch.from_numpy(y_train)
X_test = torch.from_numpy(X_test)
y_test = torch.from_numpy(y_test)

X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)

# %%
class StructuredModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_layer1 = nn.Linear(in_features = 1530, out_features = 1024)
        self.linear_layer2 = nn.Linear(in_features = 1024, out_features = 512)
        self.linear_layer3 = nn.Linear(in_features = 512, out_features = 256)
        self.linear_layer4 = nn.Linear(in_features = 256, out_features = 128)
        self.linear_layer5 = nn.Linear(in_features = 128, out_features = 64)
        self.linear_layer6 = nn.Linear(in_features = 64, out_features = 50)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        op1 = self.linear_layer1(x)
        op1a = torch.tanh(op1)
        op2 = self.linear_layer2(op1a)
        op2a = torch.tanh(op2)
        op3 = self.linear_layer3(op2a)
        op3a = torch.tanh(op3)        
        op4 = self.linear_layer4(op3a)
        op4a = torch.tanh(op4)
        op5 = self.linear_layer5(op4a)
        op5a = torch.tanh(op5)
        op6 = self.linear_layer6(op5a)
        output = torch.sigmoid(op6)
        return output

# %%
smodel = StructuredModel()
smodel.to(device)
    
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params = smodel.parameters(), lr = 0.001)

epochs = 500

for epoch in range(epochs):
    smodel.train()
    y_pred = smodel(X_train.float())
    loss = loss_fn(y_pred, y_train.float())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    smodel.eval()
    with torch.inference_mode():
        y_pred_test = smodel(X_test.float())
        loss_test = loss_fn(y_pred_test, y_test.float())
        
    if epoch %50==0:
        print(f"Epoch: {epoch} | Training Loss: {loss} | Test Loss: {loss_test}")
        scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test.cpu(), y_pred_test.cpu(), True)
        keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
        print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
        print()
# Out:
# Epoch: 0 | Training Loss: 0.903791069984436 | Test Loss: 0.8992331624031067
# {'macro_f1': '0.120', 'macro_auc': '0.503', 'micro_f1': '0.218', 'micro_auc': '0.479'}
#
# Epoch: 50 | Training Loss: 0.9029311537742615 | Test Loss: 0.8984373211860657
# {'macro_f1': '0.119', 'macro_auc': '0.495', 'micro_f1': '0.225', 'micro_auc': '0.485'}
#
# Epoch: 100 | Training Loss: 0.9026227593421936 | Test Loss: 0.8981298804283142
# {'macro_f1': '0.109', 'macro_auc': '0.491', 'micro_f1': '0.212', 'micro_auc': '0.488'}
#
# Epoch: 150 | Training Loss: 0.9023719429969788 | Test Loss: 0.8978841304779053
# {'macro_f1': '0.109', 'macro_auc': '0.498', 'micro_f1': '0.212', 'micro_auc': '0.489'}
#
# Epoch: 200 | Training Loss: 0.9018869996070862 | Test Loss: 0.8973725438117981
# {'macro_f1': '0.115', 'macro_auc': '0.501', 'micro_f1': '0.225', 'micro_auc': '0.488'}
#
# Epoch: 250 | Training Loss: 0.9015653729438782 | Test Loss: 0.8970484137535095
# {'macro_f1': '0.101', 'macro_auc': '0.481', 'micro_f1': '0.211', 'micro_auc': '0.487'}
#
# Epoch: 300 | Training Loss: 0.9013184309005737 | Test Loss: 0.8968032598495483
# {'macro_f1': '0.098', 'macro_auc': '0.484', 'micro_f1': '0.212', 'micro_auc': '0.487'}
#
# Epoch: 350 | Training Loss: 0.9010019302368164 | Test Loss: 0.8964582085609436
# {'macro_f1': '0.101', 'macro_auc': '0.485', 'micro_f1': '0.210', 'micro_auc': '0.486'}
#
# Epoch: 400 | Training Loss: 0.9007494449615479 | Test Loss: 0.8962120413780212
# {'macro_f1': '0.101', 'macro_auc': '0.490', 'micro_f1': '0.210', 'micro_auc': '0.486'}
#
# Epoch: 450 | Training Loss: 0.90044105052948 | Test Loss: 0.8959020376205444
# {'macro_f1': '0.098', 'macro_auc': '0.504', 'micro_f1': '0.213', 'micro_auc': '0.483'}

# %%
struct_input = y_pred_test

# %%
struct_input = struct_input.cpu().numpy()
struct_input
# Out:
# array([[0.5259618 , 0.45861647, 0.52732325, ..., 0.4997866 , 0.46765682,
#         0.50924075],
#        [0.5259618 , 0.45861644, 0.52732325, ..., 0.4997866 , 0.46765682,
#         0.50924075],
#        [0.5259618 , 0.45861647, 0.52732325, ..., 0.4997866 , 0.46765682,
#         0.50924075],
#        ...,
#        [0.5259618 , 0.45861647, 0.52732325, ..., 0.4997866 , 0.46765682,
#         0.50924075],
#        [0.5259618 , 0.45861647, 0.52732325, ..., 0.4997866 , 0.46765682,
#         0.50924075],
#        [0.5259618 , 0.45861647, 0.52732325, ..., 0.4997866 , 0.46765682,
#         0.50924075]], dtype=float32)

# %%
mi_auc = []
ma_auc = []
mi_f1 = []
ma_f1 = []

for alpha in np.arange(0.0, 1.0, 0.001):
    final_output = struct_input * alpha + unstruct_input * (1 - alpha)
    scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test.cpu(), final_output, True)
    keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
    print('aplha: ', alpha)
    print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
    mi_auc.append(scores['micro_auc'])
    ma_auc.append(scores['macro_auc'])
    mi_f1.append(scores['micro_f1'])
    ma_f1.append(scores['macro_f1'])
    print('\n')
# Out:
# aplha:  0.0
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.004
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.005
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.006
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.007
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.008
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.009000000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.01
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.011
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.012
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.013000000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.014
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.015
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.016
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.017
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.018000000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.019
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.02
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.021
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.022
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.023
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.024
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.025
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.026000000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.027
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.028
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.029
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.03
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.031
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.032
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.033
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.034
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.035
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.036000000000000004
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.037
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.038
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.039
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.04
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.041
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.042
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.043000000000000003
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.044
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.045
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.046
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.047
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.048
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.049
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.05
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.051000000000000004
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.052000000000000005
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.053
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.054
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.055
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.056
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.057
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.058
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.059000000000000004
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.06
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.061
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.062
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.063
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.064
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.065
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.066
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.067
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.068
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.069
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.07
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.07100000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.07200000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.073
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.074
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.075
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.076
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.077
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.078
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.079
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
# aplha:  0.08
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.081
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.082
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.083
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.084
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.085
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.08600000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.08700000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.088
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.089
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.09
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.091
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.092
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.093
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.094
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.095
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.096
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.097
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.098
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.099
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.1
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.101
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.10200000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.10300000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.10400000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.105
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.106
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.107
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.108
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.109
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.11
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.111
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.112
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.113
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.114
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.115
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.116
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.117
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.11800000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.11900000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.12
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.121
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.122
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.123
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.124
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.125
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.126
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.127
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.128
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.129
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.13
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.131
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.132
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.133
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.134
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.135
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.136
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.137
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.138
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.139
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.14
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.14100000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.14200000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.14300000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.14400000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.145
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.146
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.147
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.148
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.149
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.15
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.151
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.152
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.153
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.154
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.155
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.156
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.157
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.158
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.159
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
# aplha:  0.16
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.161
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.162
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.163
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.164
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.165
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.166
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.167
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.168
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.924'}
#
#
# aplha:  0.169
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.17
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.171
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.17200000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.17300000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.17400000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.17500000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.176
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.177
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.178
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.179
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.18
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.181
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.182
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.183
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.184
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.185
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.186
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.187
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.188
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.189
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.19
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.191
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.192
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.193
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.194
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.195
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.196
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.197
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.198
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.199
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.2
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.201
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.202
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.203
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.20400000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.20500000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.20600000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.20700000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.20800000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.209
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.21
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.211
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.212
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.213
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.214
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.215
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.216
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.217
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.218
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.219
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.22
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.221
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.222
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.223
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.224
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.225
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.226
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.227
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.228
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.229
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.23
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.231
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.232
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.233
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.234
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.23500000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.23600000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.23700000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.23800000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.23900000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
# aplha:  0.24
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.241
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.242
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.243
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.244
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.245
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.246
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.247
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.248
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.249
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.25
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.251
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.252
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.253
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.254
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.255
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.256
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.257
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.258
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.259
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.26
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.261
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.262
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.263
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.264
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.923'}
#
#
# aplha:  0.265
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.266
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.267
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.268
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.269
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.27
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.271
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.272
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.273
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.274
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.275
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.276
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.277
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.278
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.279
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.281
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28200000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28300000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28400000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28500000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28600000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28700000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.28800000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.289
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.29
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.291
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.292
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.293
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.294
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.295
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.296
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.297
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.298
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.299
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.3
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.301
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.302
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.303
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.304
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.305
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.306
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.307
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.308
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.309
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.31
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.311
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.312
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.313
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.314
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.315
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.316
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.317
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.318
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.319
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
# aplha:  0.32
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.321
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.322
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.323
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.324
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.325
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.326
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.327
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.328
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.329
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.33
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.331
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.332
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.333
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.334
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.335
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.336
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.337
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.338
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.339
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.34
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.341
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.342
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.343
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.34400000000000003
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.34500000000000003
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.34600000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.34700000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.922'}
#
#
# aplha:  0.34800000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.34900000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.35000000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.35100000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.352
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.353
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.354
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.355
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.356
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.357
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.358
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.359
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.36
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.361
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.362
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.363
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.364
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.365
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.366
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.367
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.368
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.369
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.37
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.371
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.372
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.373
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.374
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.375
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.376
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.377
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.378
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.379
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.38
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.381
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.382
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.383
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.384
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.385
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.386
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.387
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.388
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.389
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.39
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.391
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.392
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.393
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.394
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.395
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.396
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.397
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.398
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.399
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
# aplha:  0.4
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.401
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.402
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.403
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.404
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.405
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.406
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.40700000000000003
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.40800000000000003
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.921'}
#
#
# aplha:  0.40900000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41000000000000003
# {'macro_f1': '0.663', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41100000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41200000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41300000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41400000000000003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41500000000000004
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.41600000000000004
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.417
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.418
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.419
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.42
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.421
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.422
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.423
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.424
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.425
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.426
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.427
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.428
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.429
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.43
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.431
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.432
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.433
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.434
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.435
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.436
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.437
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.438
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.439
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.44
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.441
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.442
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.443
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.444
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.445
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.446
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.447
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.448
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.449
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.45
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.451
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.452
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.453
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.454
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.455
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.456
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.457
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.920'}
#
#
# aplha:  0.458
# ...
#
#
# aplha:  0.848
# {'macro_f1': '0.659', 'macro_auc': '0.898', 'micro_f1': '0.675', 'micro_auc': '0.897'}
#
#
# aplha:  0.849
# {'macro_f1': '0.658', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.897'}
#
#
# aplha:  0.85
# {'macro_f1': '0.658', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.897'}
#
#
# aplha:  0.851
# {'macro_f1': '0.658', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.897'}
#
#
# aplha:  0.852
# {'macro_f1': '0.659', 'macro_auc': '0.898', 'micro_f1': '0.675', 'micro_auc': '0.897'}
#
#
# aplha:  0.853
# {'macro_f1': '0.659', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.896'}
#
#
# aplha:  0.854
# {'macro_f1': '0.659', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.896'}
#
#
# aplha:  0.855
# {'macro_f1': '0.658', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.896'}
#
#
# aplha:  0.856
# {'macro_f1': '0.659', 'macro_auc': '0.898', 'micro_f1': '0.674', 'micro_auc': '0.896'}
#
#
# aplha:  0.857
# {'macro_f1': '0.659', 'macro_auc': '0.898', 'micro_f1': '0.673', 'micro_auc': '0.895'}
#
#
# aplha:  0.858
# {'macro_f1': '0.658', 'macro_auc': '0.898', 'micro_f1': '0.672', 'micro_auc': '0.895'}
#
#
# aplha:  0.859
# {'macro_f1': '0.658', 'macro_auc': '0.898', 'micro_f1': '0.672', 'micro_auc': '0.895'}
#
#
# aplha:  0.86
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.672', 'micro_auc': '0.895'}
#
#
# aplha:  0.861
# {'macro_f1': '0.656', 'macro_auc': '0.898', 'micro_f1': '0.671', 'micro_auc': '0.895'}
#
#
# aplha:  0.862
# {'macro_f1': '0.656', 'macro_auc': '0.898', 'micro_f1': '0.670', 'micro_auc': '0.894'}
#
#
# aplha:  0.863
# {'macro_f1': '0.656', 'macro_auc': '0.898', 'micro_f1': '0.670', 'micro_auc': '0.894'}
#
#
# aplha:  0.864
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.669', 'micro_auc': '0.894'}
#
#
# aplha:  0.865
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.669', 'micro_auc': '0.894'}
#
#
# aplha:  0.866
# {'macro_f1': '0.653', 'macro_auc': '0.898', 'micro_f1': '0.668', 'micro_auc': '0.893'}
#
#
# aplha:  0.867
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.668', 'micro_auc': '0.893'}
#
#
# aplha:  0.868
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.668', 'micro_auc': '0.893'}
#
#
# aplha:  0.869
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.667', 'micro_auc': '0.893'}
#
#
# aplha:  0.87
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.667', 'micro_auc': '0.892'}
#
#
# aplha:  0.871
# {'macro_f1': '0.655', 'macro_auc': '0.898', 'micro_f1': '0.667', 'micro_auc': '0.892'}
#
#
# aplha:  0.872
# {'macro_f1': '0.655', 'macro_auc': '0.898', 'micro_f1': '0.667', 'micro_auc': '0.892'}
#
#
# aplha:  0.873
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.666', 'micro_auc': '0.892'}
#
#
# aplha:  0.874
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.666', 'micro_auc': '0.891'}
#
#
# aplha:  0.875
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.666', 'micro_auc': '0.891'}
#
#
# aplha:  0.876
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.665', 'micro_auc': '0.891'}
#
#
# aplha:  0.877
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.664', 'micro_auc': '0.890'}
#
#
# aplha:  0.878
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.663', 'micro_auc': '0.890'}
#
#
# aplha:  0.879
# {'macro_f1': '0.653', 'macro_auc': '0.898', 'micro_f1': '0.663', 'micro_auc': '0.890'}
# aplha:  0.88
# {'macro_f1': '0.653', 'macro_auc': '0.898', 'micro_f1': '0.662', 'micro_auc': '0.889'}
#
#
# aplha:  0.881
# {'macro_f1': '0.652', 'macro_auc': '0.898', 'micro_f1': '0.662', 'micro_auc': '0.889'}
#
#
# aplha:  0.882
# {'macro_f1': '0.651', 'macro_auc': '0.898', 'micro_f1': '0.661', 'micro_auc': '0.889'}
#
#
# aplha:  0.883
# {'macro_f1': '0.651', 'macro_auc': '0.898', 'micro_f1': '0.660', 'micro_auc': '0.888'}
#
#
# aplha:  0.884
# {'macro_f1': '0.652', 'macro_auc': '0.898', 'micro_f1': '0.660', 'micro_auc': '0.888'}
#
#
# aplha:  0.885
# {'macro_f1': '0.652', 'macro_auc': '0.898', 'micro_f1': '0.659', 'micro_auc': '0.888'}
#
#
# aplha:  0.886
# {'macro_f1': '0.652', 'macro_auc': '0.898', 'micro_f1': '0.659', 'micro_auc': '0.887'}
#
#
# aplha:  0.887
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.658', 'micro_auc': '0.887'}
#
#
# aplha:  0.888
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.658', 'micro_auc': '0.886'}
#
#
# aplha:  0.889
# {'macro_f1': '0.656', 'macro_auc': '0.898', 'micro_f1': '0.658', 'micro_auc': '0.886'}
#
#
# aplha:  0.89
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.658', 'micro_auc': '0.886'}
#
#
# aplha:  0.891
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.657', 'micro_auc': '0.885'}
#
#
# aplha:  0.892
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.656', 'micro_auc': '0.885'}
#
#
# aplha:  0.893
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.656', 'micro_auc': '0.884'}
#
#
# aplha:  0.894
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.655', 'micro_auc': '0.884'}
#
#
# aplha:  0.895
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.654', 'micro_auc': '0.883'}
#
#
# aplha:  0.896
# {'macro_f1': '0.657', 'macro_auc': '0.898', 'micro_f1': '0.653', 'micro_auc': '0.883'}
#
#
# aplha:  0.897
# {'macro_f1': '0.656', 'macro_auc': '0.898', 'micro_f1': '0.652', 'micro_auc': '0.882'}
#
#
# aplha:  0.898
# {'macro_f1': '0.656', 'macro_auc': '0.898', 'micro_f1': '0.650', 'micro_auc': '0.882'}
#
#
# aplha:  0.899
# {'macro_f1': '0.655', 'macro_auc': '0.898', 'micro_f1': '0.649', 'micro_auc': '0.881'}
#
#
# aplha:  0.9
# {'macro_f1': '0.654', 'macro_auc': '0.898', 'micro_f1': '0.647', 'micro_auc': '0.881'}
#
#
# aplha:  0.901
# {'macro_f1': '0.653', 'macro_auc': '0.898', 'micro_f1': '0.645', 'micro_auc': '0.880'}
#
#
# aplha:  0.902
# {'macro_f1': '0.652', 'macro_auc': '0.898', 'micro_f1': '0.643', 'micro_auc': '0.880'}
#
#
# aplha:  0.903
# {'macro_f1': '0.641', 'macro_auc': '0.898', 'micro_f1': '0.642', 'micro_auc': '0.879'}
#
#
# aplha:  0.904
# {'macro_f1': '0.640', 'macro_auc': '0.898', 'micro_f1': '0.640', 'micro_auc': '0.879'}
#
#
# aplha:  0.905
# {'macro_f1': '0.640', 'macro_auc': '0.898', 'micro_f1': '0.639', 'micro_auc': '0.878'}
#
#
# aplha:  0.906
# {'macro_f1': '0.638', 'macro_auc': '0.898', 'micro_f1': '0.636', 'micro_auc': '0.877'}
#
#
# aplha:  0.907
# {'macro_f1': '0.637', 'macro_auc': '0.898', 'micro_f1': '0.634', 'micro_auc': '0.877'}
#
#
# aplha:  0.908
# {'macro_f1': '0.636', 'macro_auc': '0.898', 'micro_f1': '0.632', 'micro_auc': '0.876'}
#
#
# aplha:  0.909
# {'macro_f1': '0.634', 'macro_auc': '0.898', 'micro_f1': '0.629', 'micro_auc': '0.875'}
#
#
# aplha:  0.91
# {'macro_f1': '0.632', 'macro_auc': '0.898', 'micro_f1': '0.625', 'micro_auc': '0.875'}
#
#
# aplha:  0.911
# {'macro_f1': '0.631', 'macro_auc': '0.898', 'micro_f1': '0.622', 'micro_auc': '0.874'}
#
#
# aplha:  0.912
# {'macro_f1': '0.630', 'macro_auc': '0.898', 'micro_f1': '0.617', 'micro_auc': '0.873'}
#
#
# aplha:  0.913
# {'macro_f1': '0.629', 'macro_auc': '0.898', 'micro_f1': '0.614', 'micro_auc': '0.872'}
#
#
# aplha:  0.914
# {'macro_f1': '0.629', 'macro_auc': '0.898', 'micro_f1': '0.610', 'micro_auc': '0.872'}
#
#
# aplha:  0.915
# {'macro_f1': '0.616', 'macro_auc': '0.898', 'micro_f1': '0.608', 'micro_auc': '0.871'}
#
#
# aplha:  0.916
# {'macro_f1': '0.616', 'macro_auc': '0.898', 'micro_f1': '0.606', 'micro_auc': '0.870'}
#
#
# aplha:  0.917
# {'macro_f1': '0.615', 'macro_auc': '0.898', 'micro_f1': '0.603', 'micro_auc': '0.869'}
#
#
# aplha:  0.918
# {'macro_f1': '0.611', 'macro_auc': '0.898', 'micro_f1': '0.600', 'micro_auc': '0.868'}
#
#
# aplha:  0.919
# {'macro_f1': '0.608', 'macro_auc': '0.898', 'micro_f1': '0.597', 'micro_auc': '0.867'}
#
#
# aplha:  0.92
# {'macro_f1': '0.610', 'macro_auc': '0.898', 'micro_f1': '0.594', 'micro_auc': '0.866'}
#
#
# aplha:  0.921
# {'macro_f1': '0.598', 'macro_auc': '0.898', 'micro_f1': '0.589', 'micro_auc': '0.865'}
#
#
# aplha:  0.922
# {'macro_f1': '0.587', 'macro_auc': '0.898', 'micro_f1': '0.584', 'micro_auc': '0.864'}
#
#
# aplha:  0.923
# {'macro_f1': '0.576', 'macro_auc': '0.898', 'micro_f1': '0.582', 'micro_auc': '0.863'}
#
#
# aplha:  0.924
# {'macro_f1': '0.575', 'macro_auc': '0.898', 'micro_f1': '0.579', 'micro_auc': '0.862'}
#
#
# aplha:  0.925
# {'macro_f1': '0.575', 'macro_auc': '0.898', 'micro_f1': '0.578', 'micro_auc': '0.861'}
#
#
# aplha:  0.926
# {'macro_f1': '0.575', 'macro_auc': '0.898', 'micro_f1': '0.576', 'micro_auc': '0.860'}
#
#
# aplha:  0.927
# {'macro_f1': '0.573', 'macro_auc': '0.898', 'micro_f1': '0.574', 'micro_auc': '0.858'}
#
#
# aplha:  0.928
# {'macro_f1': '0.573', 'macro_auc': '0.898', 'micro_f1': '0.571', 'micro_auc': '0.857'}
#
#
# aplha:  0.929
# {'macro_f1': '0.562', 'macro_auc': '0.898', 'micro_f1': '0.569', 'micro_auc': '0.855'}
#
#
# aplha:  0.93
# {'macro_f1': '0.560', 'macro_auc': '0.898', 'micro_f1': '0.567', 'micro_auc': '0.854'}
#
#
# aplha:  0.931
# {'macro_f1': '0.548', 'macro_auc': '0.898', 'micro_f1': '0.565', 'micro_auc': '0.852'}
#
#
# aplha:  0.932
# {'macro_f1': '0.547', 'macro_auc': '0.898', 'micro_f1': '0.563', 'micro_auc': '0.850'}
#
#
# aplha:  0.933
# {'macro_f1': '0.532', 'macro_auc': '0.898', 'micro_f1': '0.560', 'micro_auc': '0.848'}
#
#
# aplha:  0.934
# {'macro_f1': '0.516', 'macro_auc': '0.898', 'micro_f1': '0.557', 'micro_auc': '0.846'}
#
#
# aplha:  0.935
# {'macro_f1': '0.514', 'macro_auc': '0.898', 'micro_f1': '0.555', 'micro_auc': '0.844'}
#
#
# aplha:  0.936
# {'macro_f1': '0.505', 'macro_auc': '0.898', 'micro_f1': '0.553', 'micro_auc': '0.842'}
#
#
# aplha:  0.937
# {'macro_f1': '0.509', 'macro_auc': '0.898', 'micro_f1': '0.553', 'micro_auc': '0.840'}
#
#
# aplha:  0.9380000000000001
# {'macro_f1': '0.496', 'macro_auc': '0.898', 'micro_f1': '0.550', 'micro_auc': '0.838'}
#
#
# aplha:  0.9390000000000001
# {'macro_f1': '0.484', 'macro_auc': '0.898', 'micro_f1': '0.549', 'micro_auc': '0.835'}
#
#
# aplha:  0.9400000000000001
# {'macro_f1': '0.472', 'macro_auc': '0.898', 'micro_f1': '0.548', 'micro_auc': '0.832'}
#
#
# aplha:  0.9410000000000001
# {'macro_f1': '0.472', 'macro_auc': '0.898', 'micro_f1': '0.548', 'micro_auc': '0.830'}
#
#
# aplha:  0.9420000000000001
# {'macro_f1': '0.471', 'macro_auc': '0.898', 'micro_f1': '0.546', 'micro_auc': '0.827'}
#
#
# aplha:  0.9430000000000001
# {'macro_f1': '0.472', 'macro_auc': '0.898', 'micro_f1': '0.545', 'micro_auc': '0.824'}
#
#
# aplha:  0.9440000000000001
# {'macro_f1': '0.471', 'macro_auc': '0.898', 'micro_f1': '0.542', 'micro_auc': '0.821'}
#
#
# aplha:  0.9450000000000001
# {'macro_f1': '0.470', 'macro_auc': '0.898', 'micro_f1': '0.539', 'micro_auc': '0.818'}
#
#
# aplha:  0.9460000000000001
# {'macro_f1': '0.469', 'macro_auc': '0.898', 'micro_f1': '0.535', 'micro_auc': '0.815'}
#
#
# aplha:  0.9470000000000001
# {'macro_f1': '0.469', 'macro_auc': '0.898', 'micro_f1': '0.531', 'micro_auc': '0.811'}
#
#
# aplha:  0.9480000000000001
# {'macro_f1': '0.467', 'macro_auc': '0.898', 'micro_f1': '0.520', 'micro_auc': '0.808'}
#
#
# aplha:  0.9490000000000001
# {'macro_f1': '0.466', 'macro_auc': '0.898', 'micro_f1': '0.513', 'micro_auc': '0.804'}
#
#
# aplha:  0.9500000000000001
# {'macro_f1': '0.465', 'macro_auc': '0.898', 'micro_f1': '0.506', 'micro_auc': '0.800'}
#
#
# aplha:  0.9510000000000001
# {'macro_f1': '0.465', 'macro_auc': '0.898', 'micro_f1': '0.493', 'micro_auc': '0.796'}
#
#
# aplha:  0.9520000000000001
# {'macro_f1': '0.464', 'macro_auc': '0.898', 'micro_f1': '0.489', 'micro_auc': '0.792'}
#
#
# aplha:  0.9530000000000001
# {'macro_f1': '0.463', 'macro_auc': '0.898', 'micro_f1': '0.485', 'micro_auc': '0.788'}
#
#
# aplha:  0.9540000000000001
# {'macro_f1': '0.466', 'macro_auc': '0.898', 'micro_f1': '0.482', 'micro_auc': '0.783'}
#
#
# aplha:  0.9550000000000001
# {'macro_f1': '0.452', 'macro_auc': '0.898', 'micro_f1': '0.477', 'micro_auc': '0.779'}
#
#
# aplha:  0.9560000000000001
# {'macro_f1': '0.453', 'macro_auc': '0.898', 'micro_f1': '0.475', 'micro_auc': '0.774'}
#
#
# aplha:  0.9570000000000001
# {'macro_f1': '0.452', 'macro_auc': '0.898', 'micro_f1': '0.471', 'micro_auc': '0.770'}
#
#
# aplha:  0.9580000000000001
# {'macro_f1': '0.439', 'macro_auc': '0.898', 'micro_f1': '0.465', 'micro_auc': '0.765'}
#
#
# aplha:  0.9590000000000001
# {'macro_f1': '0.439', 'macro_auc': '0.898', 'micro_f1': '0.460', 'micro_auc': '0.760'}
# aplha:  0.96
# {'macro_f1': '0.438', 'macro_auc': '0.898', 'micro_f1': '0.453', 'micro_auc': '0.755'}
#
#
# aplha:  0.961
# {'macro_f1': '0.438', 'macro_auc': '0.898', 'micro_f1': '0.443', 'micro_auc': '0.750'}
#
#
# aplha:  0.962
# {'macro_f1': '0.436', 'macro_auc': '0.898', 'micro_f1': '0.438', 'micro_auc': '0.745'}
#
#
# aplha:  0.963
# {'macro_f1': '0.433', 'macro_auc': '0.898', 'micro_f1': '0.434', 'micro_auc': '0.740'}
#
#
# aplha:  0.964
# {'macro_f1': '0.428', 'macro_auc': '0.898', 'micro_f1': '0.431', 'micro_auc': '0.735'}
#
#
# aplha:  0.965
# {'macro_f1': '0.432', 'macro_auc': '0.898', 'micro_f1': '0.426', 'micro_auc': '0.729'}
#
#
# aplha:  0.966
# {'macro_f1': '0.418', 'macro_auc': '0.898', 'micro_f1': '0.421', 'micro_auc': '0.724'}
#
#
# aplha:  0.967
# {'macro_f1': '0.419', 'macro_auc': '0.898', 'micro_f1': '0.407', 'micro_auc': '0.718'}
#
#
# aplha:  0.968
# {'macro_f1': '0.404', 'macro_auc': '0.898', 'micro_f1': '0.400', 'micro_auc': '0.712'}
#
#
# aplha:  0.969
# {'macro_f1': '0.402', 'macro_auc': '0.898', 'micro_f1': '0.393', 'micro_auc': '0.707'}
#
#
# aplha:  0.97
# {'macro_f1': '0.398', 'macro_auc': '0.898', 'micro_f1': '0.379', 'micro_auc': '0.701'}
#
#
# aplha:  0.971
# {'macro_f1': '0.380', 'macro_auc': '0.898', 'micro_f1': '0.358', 'micro_auc': '0.696'}
#
#
# aplha:  0.972
# {'macro_f1': '0.368', 'macro_auc': '0.898', 'micro_f1': '0.356', 'micro_auc': '0.690'}
#
#
# aplha:  0.973
# {'macro_f1': '0.367', 'macro_auc': '0.898', 'micro_f1': '0.354', 'micro_auc': '0.684'}
#
#
# aplha:  0.974
# {'macro_f1': '0.352', 'macro_auc': '0.898', 'micro_f1': '0.352', 'micro_auc': '0.678'}
#
#
# aplha:  0.975
# {'macro_f1': '0.351', 'macro_auc': '0.898', 'micro_f1': '0.350', 'micro_auc': '0.672'}
#
#
# aplha:  0.976
# {'macro_f1': '0.350', 'macro_auc': '0.898', 'micro_f1': '0.349', 'micro_auc': '0.666'}
#
#
# aplha:  0.977
# {'macro_f1': '0.348', 'macro_auc': '0.898', 'micro_f1': '0.347', 'micro_auc': '0.660'}
#
#
# aplha:  0.978
# {'macro_f1': '0.346', 'macro_auc': '0.898', 'micro_f1': '0.343', 'micro_auc': '0.654'}
#
#
# aplha:  0.979
# {'macro_f1': '0.343', 'macro_auc': '0.898', 'micro_f1': '0.329', 'micro_auc': '0.648'}
#
#
# aplha:  0.98
# {'macro_f1': '0.325', 'macro_auc': '0.898', 'micro_f1': '0.322', 'micro_auc': '0.642'}
#
#
# aplha:  0.981
# {'macro_f1': '0.321', 'macro_auc': '0.898', 'micro_f1': '0.316', 'micro_auc': '0.635'}
#
#
# aplha:  0.982
# {'macro_f1': '0.301', 'macro_auc': '0.898', 'micro_f1': '0.303', 'micro_auc': '0.629'}
#
#
# aplha:  0.983
# {'macro_f1': '0.301', 'macro_auc': '0.898', 'micro_f1': '0.300', 'micro_auc': '0.623'}
#
#
# aplha:  0.984
# {'macro_f1': '0.287', 'macro_auc': '0.898', 'micro_f1': '0.286', 'micro_auc': '0.616'}
#
#
# aplha:  0.985
# {'macro_f1': '0.287', 'macro_auc': '0.898', 'micro_f1': '0.283', 'micro_auc': '0.608'}
#
#
# aplha:  0.986
# {'macro_f1': '0.253', 'macro_auc': '0.898', 'micro_f1': '0.279', 'micro_auc': '0.602'}
#
#
# aplha:  0.987
# {'macro_f1': '0.252', 'macro_auc': '0.898', 'micro_f1': '0.276', 'micro_auc': '0.595'}
#
#
# aplha:  0.988
# {'macro_f1': '0.251', 'macro_auc': '0.898', 'micro_f1': '0.274', 'micro_auc': '0.588'}
#
#
# aplha:  0.989
# {'macro_f1': '0.249', 'macro_auc': '0.898', 'micro_f1': '0.271', 'micro_auc': '0.581'}
#
#
# aplha:  0.99
# {'macro_f1': '0.232', 'macro_auc': '0.898', 'micro_f1': '0.266', 'micro_auc': '0.570'}
#
#
# aplha:  0.991
# {'macro_f1': '0.201', 'macro_auc': '0.898', 'micro_f1': '0.251', 'micro_auc': '0.561'}
#
#
# aplha:  0.992
# {'macro_f1': '0.200', 'macro_auc': '0.898', 'micro_f1': '0.250', 'micro_auc': '0.552'}
#
#
# aplha:  0.993
# {'macro_f1': '0.189', 'macro_auc': '0.898', 'micro_f1': '0.250', 'micro_auc': '0.544'}
#
#
# aplha:  0.994
# {'macro_f1': '0.188', 'macro_auc': '0.898', 'micro_f1': '0.250', 'micro_auc': '0.536'}
#
#
# aplha:  0.995
# {'macro_f1': '0.188', 'macro_auc': '0.898', 'micro_f1': '0.250', 'micro_auc': '0.530'}
#
#
# aplha:  0.996
# {'macro_f1': '0.186', 'macro_auc': '0.898', 'micro_f1': '0.249', 'micro_auc': '0.521'}
#
#
# aplha:  0.997
# {'macro_f1': '0.183', 'macro_auc': '0.898', 'micro_f1': '0.244', 'micro_auc': '0.514'}
#
#
# aplha:  0.998
# {'macro_f1': '0.149', 'macro_auc': '0.898', 'micro_f1': '0.229', 'micro_auc': '0.508'}
#
#
# aplha:  0.999
# {'macro_f1': '0.107', 'macro_auc': '0.898', 'micro_f1': '0.213', 'micro_auc': '0.495'}

# %%
alphas = np.arange(0, 1, 0.001)
mi_auc = np.array(mi_auc)
ma_auc = np.array(ma_auc)
mi_f1 = np.array(mi_f1)
ma_f1 = np.array(ma_f1)

# %%
y = mi_auc
plt.plot(alphas, y)
ymax = max(y)
xpos = np.where(y == ymax)
xmax = alphas[xpos]

plt.grid()
plt.show()

print('Max value: ', ymax, ', at alpha = ', xmax)
# Out:
# Max value:  0.9249033689797274 , at alpha =  [0.]

# %%
summ = np.add(mi_auc, ma_auc)
summ = np.add(summ, mi_f1)
summ = np.add(summ, ma_f1)

# %%
pos = np.where(summ == max(summ))
print('pos:', pos)
print('alpha:', alphas[pos])
# Out:
# pos: (array([0]),)
# alpha: [0.]

# %%
print('micro_auc:', mi_auc[pos])
print('macro_auc:', ma_auc[pos])
print('micro-f1:', mi_f1[pos])
print('macro-f1:', ma_f1[pos])
# Out:
# micro_auc: [0.92490337]
# macro_auc: [0.89753369]
# micro-f1: [0.68929647]
# macro-f1: [0.66168739]
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.6s finished

# %%
class Ensemble(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_layer = nn.Linear(in_features = 100, out_features = 50)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        output = self.linear_layer(x)
        output = torch.sigmoid(output)
        return output

# %%
final_input = np.hstack((struct_input, unstruct_input))
final_input.shape
# Out:
# (2979, 100)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    2.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    3.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    4.0s finished

# %%
final_input = torch.from_numpy(final_input)
final_test_input = torch.from_numpy(final_test_input)
y_train = torch.from_numpy(y_train)
# X_test = torch.from_numpy(X_test)
y_test = torch.from_numpy(y_test)

final_input = final_input.to(device)
final_test_input = final_test_input.to(device)
# X_train = X_train.to(device)
y_train = y_train.to(device)
# X_test = X_test.to(device)
y_test = y_test.to(device)

# %%
esmodel = Ensemble()
esmodel.to(device)
    
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params = esmodel.parameters(), lr = 0.001)

epochs = 100

for epoch in range(epochs):
    esmodel.train()
    y_pred = esmodel(final_input.float())
    loss = loss_fn(y_pred, y_train.float())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    esmodel.eval()
    with torch.inference_mode():
        y_pred_test = esmodel(final_test_input.float())
        loss_test = loss_fn(y_pred_test, y_test.float())
        
    if epoch %10==0:
        print(f"Epoch: {epoch} | Training Loss: {loss} | Test Loss: {loss_test}")
        scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test.cpu(), y_pred_test.cpu(), True)
        keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
        print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
        print()
# Out:
# Epoch: 0 | Training Loss: 0.9078075885772705 | Test Loss: 0.9025224447250366
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.226', 'micro_auc': '0.483'}
#
# Epoch: 10 | Training Loss: 0.9077938795089722 | Test Loss: 0.9025089144706726
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.226', 'micro_auc': '0.483'}
#
# Epoch: 20 | Training Loss: 0.907780110836029 | Test Loss: 0.9024954438209534
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 30 | Training Loss: 0.9077662825584412 | Test Loss: 0.9024819731712341
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 40 | Training Loss: 0.907752513885498 | Test Loss: 0.9024685621261597
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 50 | Training Loss: 0.9077386856079102 | Test Loss: 0.9024549722671509
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 60 | Training Loss: 0.907724916934967 | Test Loss: 0.9024415612220764
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 70 | Training Loss: 0.9077112078666687 | Test Loss: 0.9024280309677124
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 80 | Training Loss: 0.9076974391937256 | Test Loss: 0.9024146199226379
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.225', 'micro_auc': '0.483'}
#
# Epoch: 90 | Training Loss: 0.9076837301254272 | Test Loss: 0.9024011492729187
# {'macro_f1': '0.228', 'macro_auc': '0.503', 'micro_f1': '0.226', 'micro_auc': '0.483'}
