# %% [markdown]
# # Unstructured Model

# %%
import os
import copy
import torch
import pickle
import pprint
import random
import shutil
import random
import torch
import hashlib
import numpy as np
import pandas as pd
from rnn import RNN
import torch.nn as nn
from vocab import Vocab
from torch import optim
from util import *
from constants import *
from evaluator import Evaluator
from tqdm.notebook import tqdm
from sklearn.metrics import *
from transformers import AdamW
from collections import Counter
import torch.nn.functional as F
from collections import OrderedDict
from torch.autograd import Variable
from matplotlib import pyplot as plt
from sklearn.preprocessing import *
from embedding_layer import EmbeddingLayer
from attention_layer import AttentionLayer
from torch.nn.utils.rnn import pad_sequence
from gensim.models.word2vec import Word2Vec
from dataloaders import TextDataLoader, TextDataset
from gensim.models.keyedvectors import KeyedVectors
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
tqdm.pandas()
# Out:
# 2023-02-16 19:02:22.429189: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-16 19:02:22.593217: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !nvidia-smi
# Out:
# Thu Feb 16 19:02:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla M40 24GB      Off  | 00000000:04:00.0 Off |                    0 |
# | N/A   35C    P8    15W / 250W |      3MiB / 22945MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla M40 24GB      Off  | 00000000:82:00.0 Off |                    0 |
# | N/A   32C    P8    17W / 250W |      3MiB / 22945MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
device
# Out:
# device(type='cuda', index=1)

# %%
def read_data(file_path) -> list:
    data = pd.read_csv(file_path, on_bad_lines='skip')
    id_data = data[id_col_name]
    text_data = data[text_col_name]
    hierarchical_label_data = []
    label_data = data[label_col_name].tolist()
    output = []
    for i in tqdm(range(len(label_data)), desc="Reading data"):
        labels = label_data[i].split(';')
        output.append((text_data[i], labels, id_data[i]))
    return output

# %%
def read_labeldesc(file_path) -> list:
    data = pd.read_csv(file_path)
    desc_data = data[desc_col_name].tolist()
    label_data = data[label_col_name].tolist()
    output = []
    for i in tqdm(range(len(label_data)), desc="Reading Label Descriptions"):
        output.append((label_data[i], desc_data[i]))
    return output

# %%
def load_cached_data(file_path: str) -> tuple:
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
        f.close()
    return data["vocab"], data["training_data"], data["valid_data"], data["test_data"],data["label_desc"]

# %%
def prepare_data():
    cache_folder = "{}/{}".format(cache_dir, "mimic3_single_50")
#     device_name = 'cuda' if torch.cuda.is_available() else 'cpu'
    save_vocab_file_name = "{}.pkl".format("save_vocab")
    cached_file_name = os.path.join(cache_folder, save_vocab_file_name)
    if os.path.exists(cached_file_name):
        vocab, training_data, valid_data, test_data, label_desc = load_cached_data(cached_file_name)
        data = training_data + valid_data + test_data
        labels = []
        for (feature, l, _) in data:
            labels.extend(l)
        unique_labels=list(set(labels))
        n_labels = len(unique_labels)
        labels = unique_labels
        vocab.update_labels(labels)
        print("Loaded vocab and data from file")
    else:
        training_data = read_data( data_dir + "/ensemble_train.csv")
        valid_data = read_data( data_dir + "/ensemble_dev.csv")
        test_data = read_data( data_dir + "/ensemble_test.csv")
        label_desc = read_labeldesc(data_dir + "/D_ICD_50_ensemble.csv")
        data = training_data + valid_data + test_data
        labels = []
        for (feature, l, _) in data:
            labels.extend(l)
        unique_labels=list(set(labels))
        n_labels = len(unique_labels)
        labels = unique_labels
        vocab = Vocab(data, labels,label_desc,min_word_frequency,
                          word_embedding_mode=embedding_mode,
                          word_embedding_file=embedding_file)
        print("Preparing the vocab")
        vocab.prepare_vocab()
        saved_objects = {"vocab": vocab,
                         "training_data": training_data,
                         "valid_data": valid_data,
                         "test_data": test_data,
                         "label_desc": label_desc}
        with open(cached_file_name, 'wb') as f:
            pickle.dump(saved_objects, f, pickle.HIGHEST_PROTOCOL)
            f.close()
        print("Saved vocab and data to files")
    return training_data, valid_data, test_data ,label_desc, vocab,cached_file_name

# %%
training_data, valid_data, test_data, label_desc, vocab, saved_vocab_path = prepare_data()
# Out:
# Loaded vocab and data from file

# %%
model = RNN(vocab, device)
model
# Out:
# RNN(
#   (embedding): EmbeddingLayer(
#     (embeddings): Embedding(66379, 100)
#   )
#   (label_linear): Linear(in_features=100, out_features=256, bias=True)
#   (rnn): LSTM(100, 256, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (attention): AttentionLayer(
#     (first_linear): Linear(in_features=512, out_features=256, bias=False)
#     (second_linear): Linear(in_features=256, out_features=50, bias=False)
#     (third_linear): Linear(in_features=512, out_features=256, bias=False)
#   )
#   (classification_layer): Linear(in_features=256, out_features=50, bias=True)
# )

# %%
class Trainer:
    def __init__(self, model: nn.Module,
                 train_dataloader: TextDataLoader,
                 valid_dataloader: TextDataLoader,
                 test_dataloader: TextDataLoader,
                 criterions,
                 optimiser,
                 scheduler,
                 vocab,
                 checkpoint_path,
                 ):
        self.model = model
        self.train_dataloader = train_dataloader
        self.valid_dataloader = valid_dataloader
        self.test_dataloader = test_dataloader
        self.criterions = criterions
        self.optimiser = optimiser
        self.scheduler = scheduler
        self.vocab = vocab
        self.multilabel = multilabel
        self.checkpoint_path = checkpoint_path
        self.n_training_labels = n_labels
        self.saved_result_path = '../model/results.pkl'
        self.main_metric = main_metric
        self.start_epoch = 0
        self.best_val = None
        self.saved_test_scores = None
        self.best_epoch_num = 1

    def train_single_epoch(self, index):
        self.model.train()
        self.train_dataloader.dataset.shuffle_data()
        losses = []
        true_labels = []
        pred_probs = []
        ids = []
        all_loss_list = []
        progress_bar = tqdm(self.train_dataloader, unit="batches", desc="Training at epoch #{}".format(index))
        progress_bar.clear()
        self.optimiser.zero_grad()
        batch_id = 0

        for text_batch, label_batch, length_batch, id_batch, desc_batch in progress_bar:
            batch_id += 1
            text_batch = text_batch.to(device)
            label_batch = label_batch.to(device)
            length_batch = length_batch.to(device)
            desc_batch = desc_batch.to(device)
            true_labels.extend(label_batch.cpu().numpy())
            ids.extend(id_batch)
            output = self.model(text_batch, length_batch,desc_batch)
            loss_list = []
            loss_list = self.criterions(output, label_batch)
            all_loss_list.append([loss_list.item()])
            output = torch.sigmoid(output)
            output = output.detach().cpu().numpy()
            pred_probs.extend(output)
            loss = get_loss(loss_list, self.n_training_labels)
            loss.backward()
            losses.append(loss.item())
            self.optimiser.step()
            self.optimiser.zero_grad()

        scores = OrderedDict()
        scores = calculate_eval_metrics(ids, true_labels,pred_probs, self.multilabel)
        scores["loss"] = np.mean(all_loss_list).item()
        scores["average"] = np.mean(losses).item()
        progress_bar.refresh(True)
        progress_bar.clear(True)
        progress_bar.close()
        keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1', 'macro_P@5', 'macro_P@8', 'macro_P@15', 'loss']
        print({k:v for k,v in scores.items() if k in keys})
        return scores


    @staticmethod
    def format_number(number):
        return abs(round(number, ndigits=ndigits))

    def train(self,n_epoch: int = 100):
        best_valid_scores = self.best_val
        saved_test_scores = self.saved_test_scores
        saved_train_scores = None
        best_epoch_num = self.best_epoch_num
        evaluator = Evaluator(self.model, self.vocab, self.criterions, self.n_training_labels, device)
        for e in range(self.start_epoch + 1, n_epoch + 1):
            train_scores = self.train_single_epoch(e)
            epoch_loss = train_scores["average"]
            valid_scores = evaluator.evaluate(self.valid_dataloader)
            test_scores = evaluator.evaluate(self.test_dataloader)
            self.scheduler.step(test_scores["average"])
            print('lr {}'.format(self.optimiser.param_groups[0]['lr']))
            keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1', 'macro_P@5', 'macro_P@8', 'macro_P@15', 'loss']
            print({k:v for k,v in test_scores.items() if k in keys})
            print('\n\n')
            
            if best_valid_scores is None or best_valid_scores[self.main_metric] < valid_scores[self.main_metric]:
                best_valid_scores = valid_scores
                saved_test_scores = test_scores
                saved_train_scores = train_scores
                best_epoch_num = e
                

                    
        results = {"train": saved_train_scores, "valid": best_valid_scores, "test": saved_test_scores,
                    "index2label": self.vocab.index2label}
        with open(self.saved_result_path, 'wb') as f:
            pickle.dump(results, f, pickle.HIGHEST_PROTOCOL)
                
        return self.model, best_valid_scores

# %%
def _load_and_cache_data(train_data, valid_data, test_data, label_desc, vocab, saved_data_file_path):
    if os.path.exists(saved_data_file_path):
        try:
            with open(saved_data_file_path, 'rb') as f:
                data = pickle.load(f)
                data["train"].multilabel = bool(multilabel)
                data["valid"].multilabel = bool(multilabel)
                data["test"].multilabel = bool(multilabel)

                return data["train"], data["valid"], data["test"]
        except:
            pass

    # Build train/valid/test data loaders
    train_dataset = TextDataset(train_data, vocab, label_desc,max_seq_length=max_seq_length,min_seq_length=min_seq_length,sort=True,multilabel=multilabel)

    valid_dataset = TextDataset(valid_data, vocab, label_desc,max_seq_length=max_seq_length,min_seq_length=min_seq_length,sort=True,multilabel=multilabel)

    test_dataset = TextDataset(test_data, vocab, label_desc,max_seq_length=max_seq_length,min_seq_length=min_seq_length,sort=True, multilabel=multilabel)
    
    # try:
    with open(saved_data_file_path, 'wb') as f:
        data = {"train": train_dataset, "valid": valid_dataset, "test": test_dataset}
        pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
    
    return train_dataset, valid_dataset, test_dataset

# %%
def _train_model(train_data, valid_data, test_data, label_desc, vocab, saved_data_file_path=None,checkpoint_path=None):
    model = RNN(vocab,device)
    init_state_dict = None
    if init_state_dict is not None:
        model.load_state_dict(init_state_dict)
    model.to(device)

    train_dataset, valid_dataset, test_dataset = _load_and_cache_data(train_data, valid_data, test_data, label_desc,
                                                                      vocab, saved_data_file_path)
    
    train_dataloader = TextDataLoader(dataset=train_dataset, vocab=vocab, batch_size=batch_size)

    valid_dataloader = TextDataLoader(dataset=valid_dataset, vocab=vocab, batch_size=batch_size)

    test_dataloader = TextDataLoader(dataset=test_dataset, vocab=vocab, batch_size=batch_size)

    optimiser = torch.optim.AdamW(model.parameters(), lr = 0.001)
    
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser, 'min', patience=1)
    
    criterions = nn.BCEWithLogitsLoss(pos_weight = torch.tensor(2))

    trainer = Trainer(model=model,
                      train_dataloader=train_dataloader,
                      valid_dataloader=valid_dataloader,
                      test_dataloader=test_dataloader,
                      criterions=criterions,
                      optimiser=optimiser,
                      scheduler = scheduler,
                      vocab=vocab,
                      checkpoint_path=checkpoint_path)
    best_model, scores = trainer.train(n_epoch=n_epoch)

    evaluator = Evaluator(model=best_model,vocab=vocab,criterions=criterions,
                          n_training_labels=n_labels,device = device)

    del model, optimiser, evaluator, trainer, criterions
    return best_model, scores  # either on valid or test

# %%
def run_with_validation(training_data, valid_data, test_data, label_desc, vocab, saved_data_file_path):
    best_model, scores = _train_model(
        train_data=training_data, valid_data=valid_data, test_data=test_data, label_desc=label_desc,
        vocab=vocab, saved_data_file_path=saved_data_file_path, checkpoint_path="../model/checkpoint.pkl")

    return best_model, scores

# %%
#best_model, scores = run_with_validation(training_data, valid_data, test_data, label_desc, vocab, saved_data_file_path="{}.data.pkl".format(saved_vocab_path.split(".pkl")[0]))

# %%
#torch.save(obj = best_model.state_dict(), f = '../model/cdlaat50_for_ensemble.pth')

# %%
loaded_model = RNN(vocab, device)

# %%
loaded_model.load_state_dict(state_dict = torch.load(f = '../model/cdlaat50_for_ensemble.pth', map_location={'cuda:3':'cuda:1'}))
# Out:
# <All keys matched successfully>

# %%
loaded_model.to(device)
# Out:
# RNN(
#   (embedding): EmbeddingLayer(
#     (embeddings): Embedding(66379, 100)
#   )
#   (label_linear): Linear(in_features=100, out_features=256, bias=True)
#   (rnn): LSTM(100, 256, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (attention): AttentionLayer(
#     (first_linear): Linear(in_features=512, out_features=256, bias=False)
#     (second_linear): Linear(in_features=256, out_features=50, bias=False)
#     (third_linear): Linear(in_features=512, out_features=256, bias=False)
#   )
#   (classification_layer): Linear(in_features=256, out_features=50, bias=True)
# )

# %%
train_dataset, valid_dataset, test_dataset = _load_and_cache_data(training_data, valid_data, test_data, label_desc,
                                                                      vocab, '{}.testdata.pkl')


test_dataloader = TextDataLoader(dataset = test_dataset, vocab = vocab, batch_size = 32)

criterions = nn.BCEWithLogitsLoss(pos_weight = torch.tensor(2))
evaluator = Evaluator(model = loaded_model, vocab = vocab, criterions = criterions,
                          n_training_labels = 50, device = device)

test_scores = evaluator.evaluate(test_dataloader)
# Out:
# Evaluating:   0%|          | 0/22 [00:00<?, ?batches/s]

# %%
test_scores['pred_probs'] = np.array(test_scores['pred_probs'])
test_scores['true_labels'] = np.array(test_scores['true_labels'])
test_scores['true_labels'].shape
# Out:
# (683, 50)

# %%
# Sorting outputs according to increasing hadm ids
# print(np.array(test_scores['true_labels']))
test_scores['hadm_ids'] = np.array(test_scores['hadm_ids'])
sort = np.argsort(test_scores['hadm_ids'])
test_scores['hadm_ids'] = test_scores['hadm_ids'][sort]
test_scores['true_labels'] = test_scores['true_labels'][sort]
test_scores['pred_probs'] = test_scores['pred_probs'][sort]
# print(test_scores['true_labels'])

# %%
# df = pd.read_csv('../data/dev.csv')
# train_ids_df = pd.read_csv('../../Structured/dev_final.csv')
# train_ids = list(train_ids_df['HADM_ID'])
# len(train_ids)
# train_ensemble = df.loc[df['HADM_ID'].isin(train_ids)]
# train_ensemble.to_csv('../data/ensemble_dev.csv', index = False)

# %% [markdown]
# # Strcutured Data Pre-processing

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from sklearn.datasets import load_iris
from sklearn import tree
from sklearn.datasets import make_classification
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, jaccard_score

from sklearn.datasets import make_classification
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils import shuffle
import numpy as np

# %%
icd9 = ['401.9','38.93','428.0','427.31','414.01','96.04','96.6','584.9','250.00','96.71','272.4','518.81','99.04','39.61','599.0','530.81','96.72','272.0','285.9','88.56','244.9','486','38.91','285.1','36.15','276.2','496','99.15',
 '995.92','V58.61','507.0','038.9','88.72','585.9', '403.90','311','305.1','37.22','412','33.24','39.95','287.5','410.71','276.1','V45.81','424.0','45.13','V15.82','511.9','37.23']

# %%
icd9.sort()

# %%
# test_df = pd.read_csv('../../Structured/train_final.csv')
# test_df = test_df.sort_values('HADM_ID')

# df = pd.read_csv('../data/ensemble_train.csv')
# df = df.sort_values('HADM_ID')
# df.to_csv('../data/ensemble_train.csv', index = False)

# test_df['ICD9_CODE'] = df['ICD9_CODE'].values

# test_df.to_csv('../../Structured/train_final.csv', index = False)

# %%
train_df = pd.read_csv('../../Structured/train_final.csv')
train_dataset = train_df.to_dict('records')

test_df = pd.read_csv('../../Structured/test_final.csv')
test_dataset = test_df.to_dict('records')

dev_df = pd.read_csv('../../Structured/dev_final.csv')
dev_dataset = dev_df.to_dict('records')

# %%
def generate_dataset(dataset):
# convert df icd9_codes column into one hot vector
    for row in dataset:
        labels = [0] * 50
        codes = list(row['ICD9_CODE'].split(";"))
        for i in range(len(codes)):
            labels[icd9.index(codes[i])] = 1
        row['ICD9_CODE'] = labels

        # get list of features (lab events item ids) 
        keys = dataset[0].keys()
        keys = list(keys)
        keys.remove('SUBJECT_ID')
        keys.remove('HADM_ID')
        keys.remove('ICD9_CODE')

    # Create dataset from df feature values
    X = []
    y = []
    for row in dataset:
        x = []
        for key in keys:
            x.append(row[key])
        X.append(x)
        y.append(row['ICD9_CODE'])
    return X, y

# %%
X_train, y_train = generate_dataset(train_dataset)
X_test, y_test = generate_dataset(test_dataset)
X_train = np.array(X_train)
y_test = np.array(y_test)
y_train = np.array(y_train)
X_test = np.array(X_test)

# %% [markdown]
# # Random Forest Model for Structured data

# %%
# !pip install ada-boost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ada-boost
#   Downloading ada_boost-0.0.1-py3-none-any.whl (1.7 kB)
# Requirement already satisfied: pytz in /home3/191it205/.local/lib/python3.8/site-packages (from ada-boost) (2022.2.1)
# Installing collected packages: ada-boost
# Successfully installed ada-boost-0.0.1

# %%
import sklearn
gbm = sklearn.ensemble.GradientBoostingClassifier(learning_rate=0.05, n_estimators=100, verbose=0)
multi_target_forest = MultiOutputClassifier(gbm, n_jobs = 50)
multi_target_forest.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=GradientBoostingClassifier(learning_rate=0.05),
#                       n_jobs=50)

# %%
catb_cl = catb.CatBoostClassifier(random_state=1, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [47], line 1
# ----> 1 catb_cl = catb.CatBoostClassifier(random_state=1, verbose=True)
#
# NameError: name 'catb' is not defined

# %%
y_pred = multi_target_forest.predict_proba(X_test)

# %%
y_pred = np.array(y_pred)
struct_input = y_pred[:, :, 1]
struct_input = struct_input.T
test_samples = y_test

# %%
unstruct_input = test_scores['pred_probs']

# %%
(test_samples == test_scores['true_labels']).all()
# Out:
# True

# %%
struct_input
# Out:
# array([[0.20210621, 0.0128289 , 0.20110784, ..., 0.03296061, 0.04749579,
#         0.35045311],
#        [0.13983616, 0.01209778, 0.11982388, ..., 0.03044345, 0.02837893,
#         0.03313329],
#        [0.38606313, 0.72903517, 0.17513077, ..., 0.02615244, 0.04822682,
#         0.04386041],
#        ...,
#        [0.08217188, 0.01209778, 0.1336055 , ..., 0.0213982 , 0.02769404,
#         0.03932401],
#        [0.13926763, 0.0128289 , 0.30573599, ..., 0.06788831, 0.09559541,
#         0.22731852],
#        [0.1997911 , 0.02239933, 0.20169315, ..., 0.04511027, 0.05904829,
#         0.02870278]])

# %%
scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test, y_pred, True)
keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
print('aplha: ', alpha)
print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})

# %%
unstruct_input
# Out:
# array([[4.7751408e-02, 1.7731383e-03, 9.5218056e-01, ..., 1.1541433e-01,
#         1.0527295e-04, 3.2059449e-01],
#        [1.5753313e-03, 1.4505942e-03, 3.5131606e-03, ..., 2.7558835e-02,
#         5.6548924e-05, 2.0576625e-03],
#        [7.5998402e-01, 9.6885026e-01, 9.2968047e-01, ..., 2.1856572e-02,
#         6.8669426e-05, 4.3174047e-03],
#        ...,
#        [7.2628056e-04, 7.8894902e-04, 1.0804902e-03, ..., 1.4808625e-02,
#         2.0465939e-05, 1.0432618e-03],
#        [1.4046600e-02, 2.6597828e-03, 7.7101529e-02, ..., 8.1099436e-02,
#         7.2544906e-04, 3.4374368e-01],
#        [8.4468246e-02, 3.4818407e-02, 1.0801047e-02, ..., 8.1080176e-02,
#         3.4901162e-04, 8.1535444e-02]], dtype=float32)

# %% [markdown]
# # Basic Ensemble Model with linear weighing of models

# %%
mi_auc = []
ma_auc = []
mi_f1 = []
ma_f1 = []

for alpha in np.arange(0.0, 1.0, 0.001):
    final_output = struct_input * alpha + unstruct_input * (1 - alpha)
    scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test, final_output, True)
    keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
    print('aplha: ', alpha)
    print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
    mi_auc.append(scores['micro_auc'])
    ma_auc.append(scores['macro_auc'])
    mi_f1.append(scores['micro_f1'])
    ma_f1.append(scores['macro_f1'])
    print('\n')
# Out:
# aplha:  0.0
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.001
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.002
# {'macro_f1': '0.661', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.003
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.004
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.689', 'micro_auc': '0.925'}
#
#
# aplha:  0.005
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.925'}
#
#
# aplha:  0.006
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.007
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.008
# {'macro_f1': '0.662', 'macro_auc': '0.898', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.009000000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.01
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.011
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.012
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.013000000000000001
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.014
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.015
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.016
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.017
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.018000000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.019
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.02
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.926'}
#
#
# aplha:  0.021
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.022
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.023
# {'macro_f1': '0.663', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.024
# {'macro_f1': '0.662', 'macro_auc': '0.899', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.025
# {'macro_f1': '0.662', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.026000000000000002
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.027
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.028
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.029
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.03
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.031
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.032
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.690', 'micro_auc': '0.927'}
#
#
# aplha:  0.033
# {'macro_f1': '0.664', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.034
# {'macro_f1': '0.664', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.035
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.036000000000000004
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.037
# {'macro_f1': '0.664', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.038
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.039
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.04
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.041
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.042
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.043000000000000003
# {'macro_f1': '0.664', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.044
# {'macro_f1': '0.664', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.927'}
#
#
# aplha:  0.045
# {'macro_f1': '0.663', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.046
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.047
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.048
# {'macro_f1': '0.661', 'macro_auc': '0.900', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.049
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.05
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.051000000000000004
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.052000000000000005
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.053
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.054
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.055
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.056
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.057
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.058
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.059000000000000004
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.06
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.061
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.062
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.063
# {'macro_f1': '0.662', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.064
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.065
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.066
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.067
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.068
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.069
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.07
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.07100000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.07200000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.073
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.074
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.075
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.076
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.077
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.078
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.079
# {'macro_f1': '0.661', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
# aplha:  0.08
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.081
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.082
# {'macro_f1': '0.660', 'macro_auc': '0.901', 'micro_f1': '0.691', 'micro_auc': '0.928'}
#
#
# aplha:  0.083
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.084
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.085
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.08600000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.08700000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.088
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.089
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.09
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.091
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.092
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.093
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.094
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.095
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.096
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.097
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.098
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.099
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.1
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.101
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.10200000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.10300000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.10400000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.105
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.106
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.107
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.108
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.109
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.11
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.111
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.112
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.113
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.114
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.115
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.116
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.117
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.11800000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.11900000000000001
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.12
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.121
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.122
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.123
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.124
# {'macro_f1': '0.660', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.125
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.126
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.127
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.128
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.129
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.13
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.131
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.132
# {'macro_f1': '0.661', 'macro_auc': '0.902', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.133
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.134
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.135
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.136
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.137
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.692', 'micro_auc': '0.929'}
#
#
# aplha:  0.138
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.139
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.14
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.14100000000000001
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.14200000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.14300000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.14400000000000002
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.145
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.146
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.147
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.929'}
#
#
# aplha:  0.148
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.149
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.15
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.151
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.152
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.153
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.154
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.155
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.156
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.157
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.158
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.159
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
# aplha:  0.16
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.161
# {'macro_f1': '0.661', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.162
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.163
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.164
# {'macro_f1': '0.664', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.165
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.166
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.167
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.168
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.169
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.17
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.171
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.17200000000000001
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.17300000000000001
# {'macro_f1': '0.663', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.17400000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.17500000000000002
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.176
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.177
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.178
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.179
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.18
# {'macro_f1': '0.662', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.181
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.182
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.183
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.184
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.185
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.186
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.187
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.188
# {'macro_f1': '0.656', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.189
# {'macro_f1': '0.659', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.19
# {'macro_f1': '0.659', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.191
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.192
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.193
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.194
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.195
# {'macro_f1': '0.659', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.196
# {'macro_f1': '0.659', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.197
# {'macro_f1': '0.659', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.198
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.199
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.2
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.201
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.202
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.203
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.20400000000000001
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.20500000000000002
# {'macro_f1': '0.657', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.20600000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.903', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.20700000000000002
# {'macro_f1': '0.657', 'macro_auc': '0.903', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.20800000000000002
# {'macro_f1': '0.657', 'macro_auc': '0.903', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.209
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.21
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.211
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.212
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.213
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.214
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.215
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.216
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.217
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.218
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.219
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.22
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.221
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.222
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.223
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.224
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.225
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.226
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.227
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.228
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.229
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.23
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.231
# {'macro_f1': '0.659', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.232
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.691', 'micro_auc': '0.930'}
#
#
# aplha:  0.233
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.234
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.23500000000000001
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.23600000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.23700000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.23800000000000002
# {'macro_f1': '0.658', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.23900000000000002
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.24
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
# aplha:  0.241
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.242
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.243
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.244
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.245
# {'macro_f1': '0.657', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.246
# {'macro_f1': '0.656', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.247
# {'macro_f1': '0.656', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.248
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.249
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.25
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.251
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.252
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.253
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.254
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.255
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.256
# {'macro_f1': '0.655', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.257
# {'macro_f1': '0.654', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.258
# {'macro_f1': '0.654', 'macro_auc': '0.904', 'micro_f1': '0.690', 'micro_auc': '0.930'}
#
#
# aplha:  0.259
# {'macro_f1': '0.654', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.26
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.261
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.262
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.263
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.264
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.265
# {'macro_f1': '0.654', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.266
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.267
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.268
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.269
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.27
# {'macro_f1': '0.653', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.271
# {'macro_f1': '0.652', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.272
# {'macro_f1': '0.652', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.273
# {'macro_f1': '0.652', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.274
# {'macro_f1': '0.652', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.275
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.276
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.277
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.278
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.279
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.281
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28200000000000003
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28300000000000003
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28400000000000003
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28500000000000003
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28600000000000003
# {'macro_f1': '0.651', 'macro_auc': '0.904', 'micro_f1': '0.689', 'micro_auc': '0.930'}
#
#
# aplha:  0.28700000000000003
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.28800000000000003
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.289
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.29
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.291
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.292
# {'macro_f1': '0.649', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.293
# {'macro_f1': '0.649', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.294
# {'macro_f1': '0.649', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.295
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.296
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.297
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.298
# {'macro_f1': '0.650', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.299
# {'macro_f1': '0.639', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.3
# {'macro_f1': '0.639', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.301
# {'macro_f1': '0.639', 'macro_auc': '0.904', 'micro_f1': '0.688', 'micro_auc': '0.930'}
#
#
# aplha:  0.302
# {'macro_f1': '0.638', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.303
# {'macro_f1': '0.638', 'macro_auc': '0.904', 'micro_f1': '0.687', 'micro_auc': '0.930'}
#
#
# aplha:  0.304
# {'macro_f1': '0.637', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.305
# {'macro_f1': '0.636', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.306
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.307
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.308
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.309
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.31
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.311
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.312
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.313
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.314
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.315
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.316
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.317
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.318
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.319
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.32
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.321
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.322
# {'macro_f1': '0.634', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
# aplha:  0.323
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.324
# {'macro_f1': '0.635', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.325
# {'macro_f1': '0.634', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.326
# {'macro_f1': '0.634', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.327
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.328
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.329
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.33
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.331
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.332
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.333
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.334
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.335
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.336
# {'macro_f1': '0.634', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.337
# {'macro_f1': '0.634', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.338
# {'macro_f1': '0.634', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.339
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.34
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.341
# {'macro_f1': '0.632', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.342
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.343
# {'macro_f1': '0.632', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.34400000000000003
# {'macro_f1': '0.632', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.34500000000000003
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.34600000000000003
# {'macro_f1': '0.633', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.34700000000000003
# {'macro_f1': '0.632', 'macro_auc': '0.904', 'micro_f1': '0.686', 'micro_auc': '0.930'}
#
#
# aplha:  0.34800000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.34900000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.35000000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.35100000000000003
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.352
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.353
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.354
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.355
# {'macro_f1': '0.631', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.356
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.357
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.358
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.685', 'micro_auc': '0.930'}
#
#
# aplha:  0.359
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.36
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.361
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.362
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.363
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.364
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.365
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.366
# {'macro_f1': '0.630', 'macro_auc': '0.904', 'micro_f1': '0.684', 'micro_auc': '0.930'}
#
#
# aplha:  0.367
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.368
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.369
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.37
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.371
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.372
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.373
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.374
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.375
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.376
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.377
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.378
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.379
# {'macro_f1': '0.629', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.930'}
#
#
# aplha:  0.38
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.381
# {'macro_f1': '0.628', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.382
# {'macro_f1': '0.627', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.383
# {'macro_f1': '0.627', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.384
# {'macro_f1': '0.626', 'macro_auc': '0.904', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.385
# {'macro_f1': '0.626', 'macro_auc': '0.905', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.386
# {'macro_f1': '0.626', 'macro_auc': '0.905', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.387
# {'macro_f1': '0.626', 'macro_auc': '0.905', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.388
# {'macro_f1': '0.626', 'macro_auc': '0.905', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.389
# {'macro_f1': '0.626', 'macro_auc': '0.905', 'micro_f1': '0.683', 'micro_auc': '0.929'}
#
#
# aplha:  0.39
# {'macro_f1': '0.626', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.391
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.392
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.393
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.394
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.395
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.396
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.682', 'micro_auc': '0.929'}
#
#
# aplha:  0.397
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.681', 'micro_auc': '0.929'}
#
#
# aplha:  0.398
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.681', 'micro_auc': '0.929'}
#
#
# aplha:  0.399
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.4
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.401
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.402
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.681', 'micro_auc': '0.929'}
# aplha:  0.403
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.681', 'micro_auc': '0.929'}
#
#
# aplha:  0.404
# {'macro_f1': '0.625', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.405
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.406
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.40700000000000003
# {'macro_f1': '0.624', 'macro_auc': '0.905', 'micro_f1': '0.680', 'micro_auc': '0.929'}
#
#
# aplha:  0.40800000000000003
# {'macro_f1': '0.623', 'macro_auc': '0.905', 'micro_f1': '0.679', 'micro_auc': '0.929'}
#
#
# aplha:  0.40900000000000003
# {'macro_f1': '0.623', 'macro_auc': '0.905', 'micro_f1': '0.679', 'micro_auc': '0.929'}
#
#
# aplha:  0.41000000000000003
# {'macro_f1': '0.623', 'macro_auc': '0.905', 'micro_f1': '0.679', 'micro_auc': '0.929'}
#
#
# aplha:  0.41100000000000003
# {'macro_f1': '0.623', 'macro_auc': '0.905', 'micro_f1': '0.679', 'micro_auc': '0.929'}
#
#
# aplha:  0.41200000000000003
# {'macro_f1': '0.622', 'macro_auc': '0.905', 'micro_f1': '0.679', 'micro_auc': '0.929'}
#
#
# aplha:  0.41300000000000003
# {'macro_f1': '0.621', 'macro_auc': '0.905', 'micro_f1': '0.678', 'micro_auc': '0.929'}
#
#
# aplha:  0.41400000000000003
# {'macro_f1': '0.621', 'macro_auc': '0.905', 'micro_f1': '0.678', 'micro_auc': '0.929'}
#
#
# aplha:  0.41500000000000004
# {'macro_f1': '0.620', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.41600000000000004
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.417
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.418
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.419
# {'macro_f1': '0.620', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.42
# {'macro_f1': '0.620', 'macro_auc': '0.905', 'micro_f1': '0.678', 'micro_auc': '0.929'}
#
#
# aplha:  0.421
# {'macro_f1': '0.620', 'macro_auc': '0.905', 'micro_f1': '0.678', 'micro_auc': '0.929'}
#
#
# aplha:  0.422
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.423
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.424
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.425
# {'macro_f1': '0.618', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.426
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.676', 'micro_auc': '0.929'}
#
#
# aplha:  0.427
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.676', 'micro_auc': '0.929'}
#
#
# aplha:  0.428
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.429
# {'macro_f1': '0.620', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.43
# {'macro_f1': '0.619', 'macro_auc': '0.905', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.431
# {'macro_f1': '0.618', 'macro_auc': '0.904', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.432
# {'macro_f1': '0.619', 'macro_auc': '0.904', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.433
# {'macro_f1': '0.619', 'macro_auc': '0.904', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.434
# {'macro_f1': '0.619', 'macro_auc': '0.904', 'micro_f1': '0.677', 'micro_auc': '0.929'}
#
#
# aplha:  0.435
# {'macro_f1': '0.618', 'macro_auc': '0.904', 'micro_f1': '0.676', 'micro_auc': '0.929'}
#
#
# aplha:  0.436
# {'macro_f1': '0.618', 'macro_auc': '0.904', 'micro_f1': '0.676', 'micro_auc': '0.929'}
#
#
# aplha:  0.437
# {'macro_f1': '0.616', 'macro_auc': '0.904', 'micro_f1': '0.675', 'micro_auc': '0.929'}
#
#
# aplha:  0.438
# {'macro_f1': '0.616', 'macro_auc': '0.904', 'micro_f1': '0.675', 'micro_auc': '0.929'}
#
#
# aplha:  0.439
# {'macro_f1': '0.616', 'macro_auc': '0.904', 'micro_f1': '0.675', 'micro_auc': '0.929'}
#
#
# aplha:  0.44
# {'macro_f1': '0.615', 'macro_auc': '0.904', 'micro_f1': '0.674', 'micro_auc': '0.929'}
#
#
# aplha:  0.441
# {'macro_f1': '0.615', 'macro_auc': '0.904', 'micro_f1': '0.674', 'micro_auc': '0.929'}
#
#
# aplha:  0.442
# {'macro_f1': '0.615', 'macro_auc': '0.904', 'micro_f1': '0.674', 'micro_auc': '0.929'}
#
#
# aplha:  0.443
# {'macro_f1': '0.614', 'macro_auc': '0.904', 'micro_f1': '0.674', 'micro_auc': '0.929'}
#
#
# aplha:  0.444
# {'macro_f1': '0.614', 'macro_auc': '0.904', 'micro_f1': '0.673', 'micro_auc': '0.929'}
#
#
# aplha:  0.445
# {'macro_f1': '0.613', 'macro_auc': '0.904', 'micro_f1': '0.672', 'micro_auc': '0.929'}
#
#
# aplha:  0.446
# {'macro_f1': '0.611', 'macro_auc': '0.904', 'micro_f1': '0.672', 'micro_auc': '0.929'}
#
#
# aplha:  0.447
# {'macro_f1': '0.611', 'macro_auc': '0.904', 'micro_f1': '0.671', 'micro_auc': '0.929'}
#
#
# aplha:  0.448
# {'macro_f1': '0.610', 'macro_auc': '0.904', 'micro_f1': '0.672', 'micro_auc': '0.929'}
#
#
# aplha:  0.449
# {'macro_f1': '0.610', 'macro_auc': '0.904', 'micro_f1': '0.671', 'micro_auc': '0.929'}
#
#
# aplha:  0.45
# {'macro_f1': '0.610', 'macro_auc': '0.904', 'micro_f1': '0.671', 'micro_auc': '0.929'}
#
#
# aplha:  0.451
# {'macro_f1': '0.609', 'macro_auc': '0.904', 'micro_f1': '0.671', 'micro_auc': '0.929'}
#
#
# aplha:  0.452
# {'macro_f1': '0.608', 'macro_auc': '0.904', 'micro_f1': '0.671', 'micro_auc': '0.929'}
#
#
# aplha:  0.453
# {'macro_f1': '0.608', 'macro_auc': '0.904', 'micro_f1': '0.670', 'micro_auc': '0.929'}
#
#
# aplha:  0.454
# {'macro_f1': '0.608', 'macro_auc': '0.904', 'micro_f1': '0.671', 'micro_auc': '0.929'}
#
#
# aplha:  0.455
# {'macro_f1': '0.607', 'macro_auc': '0.904', 'micro_f1': '0.670', 'micro_auc': '0.929'}
#
#
# aplha:  0.456
# {'macro_f1': '0.606', 'macro_auc': '0.904', 'micro_f1': '0.669', 'micro_auc': '0.929'}
#
#
# aplha:  0.457
# {'macro_f1': '0.605', 'macro_auc': '0.904', 'micro_f1': '0.669', 'micro_auc': '0.929'}
#
#
# aplha:  0.458
# ...
#
#
# aplha:  0.848
# {'macro_f1': '0.357', 'macro_auc': '0.880', 'micro_f1': '0.438', 'micro_auc': '0.898'}
#
#
# aplha:  0.849
# {'macro_f1': '0.357', 'macro_auc': '0.880', 'micro_f1': '0.438', 'micro_auc': '0.898'}
#
#
# aplha:  0.85
# {'macro_f1': '0.355', 'macro_auc': '0.880', 'micro_f1': '0.437', 'micro_auc': '0.898'}
#
#
# aplha:  0.851
# {'macro_f1': '0.354', 'macro_auc': '0.880', 'micro_f1': '0.436', 'micro_auc': '0.898'}
#
#
# aplha:  0.852
# {'macro_f1': '0.354', 'macro_auc': '0.879', 'micro_f1': '0.436', 'micro_auc': '0.897'}
#
#
# aplha:  0.853
# {'macro_f1': '0.353', 'macro_auc': '0.879', 'micro_f1': '0.435', 'micro_auc': '0.897'}
#
#
# aplha:  0.854
# {'macro_f1': '0.352', 'macro_auc': '0.879', 'micro_f1': '0.435', 'micro_auc': '0.897'}
#
#
# aplha:  0.855
# {'macro_f1': '0.352', 'macro_auc': '0.879', 'micro_f1': '0.434', 'micro_auc': '0.897'}
#
#
# aplha:  0.856
# {'macro_f1': '0.351', 'macro_auc': '0.879', 'micro_f1': '0.434', 'micro_auc': '0.897'}
#
#
# aplha:  0.857
# {'macro_f1': '0.351', 'macro_auc': '0.878', 'micro_f1': '0.433', 'micro_auc': '0.896'}
#
#
# aplha:  0.858
# {'macro_f1': '0.351', 'macro_auc': '0.878', 'micro_f1': '0.433', 'micro_auc': '0.896'}
#
#
# aplha:  0.859
# {'macro_f1': '0.350', 'macro_auc': '0.878', 'micro_f1': '0.432', 'micro_auc': '0.896'}
#
#
# aplha:  0.86
# {'macro_f1': '0.350', 'macro_auc': '0.878', 'micro_f1': '0.432', 'micro_auc': '0.896'}
#
#
# aplha:  0.861
# {'macro_f1': '0.350', 'macro_auc': '0.877', 'micro_f1': '0.431', 'micro_auc': '0.895'}
#
#
# aplha:  0.862
# {'macro_f1': '0.350', 'macro_auc': '0.877', 'micro_f1': '0.431', 'micro_auc': '0.895'}
#
#
# aplha:  0.863
# {'macro_f1': '0.349', 'macro_auc': '0.877', 'micro_f1': '0.430', 'micro_auc': '0.895'}
#
#
# aplha:  0.864
# {'macro_f1': '0.348', 'macro_auc': '0.877', 'micro_f1': '0.429', 'micro_auc': '0.895'}
#
#
# aplha:  0.865
# {'macro_f1': '0.348', 'macro_auc': '0.876', 'micro_f1': '0.429', 'micro_auc': '0.894'}
#
#
# aplha:  0.866
# {'macro_f1': '0.348', 'macro_auc': '0.876', 'micro_f1': '0.429', 'micro_auc': '0.894'}
#
#
# aplha:  0.867
# {'macro_f1': '0.348', 'macro_auc': '0.876', 'micro_f1': '0.428', 'micro_auc': '0.894'}
#
#
# aplha:  0.868
# {'macro_f1': '0.347', 'macro_auc': '0.876', 'micro_f1': '0.428', 'micro_auc': '0.894'}
#
#
# aplha:  0.869
# {'macro_f1': '0.347', 'macro_auc': '0.875', 'micro_f1': '0.427', 'micro_auc': '0.893'}
#
#
# aplha:  0.87
# {'macro_f1': '0.347', 'macro_auc': '0.875', 'micro_f1': '0.427', 'micro_auc': '0.893'}
#
#
# aplha:  0.871
# {'macro_f1': '0.347', 'macro_auc': '0.875', 'micro_f1': '0.427', 'micro_auc': '0.893'}
#
#
# aplha:  0.872
# {'macro_f1': '0.347', 'macro_auc': '0.875', 'micro_f1': '0.427', 'micro_auc': '0.893'}
#
#
# aplha:  0.873
# {'macro_f1': '0.347', 'macro_auc': '0.874', 'micro_f1': '0.427', 'micro_auc': '0.893'}
#
#
# aplha:  0.874
# {'macro_f1': '0.347', 'macro_auc': '0.874', 'micro_f1': '0.426', 'micro_auc': '0.892'}
#
#
# aplha:  0.875
# {'macro_f1': '0.347', 'macro_auc': '0.874', 'micro_f1': '0.426', 'micro_auc': '0.892'}
#
#
# aplha:  0.876
# {'macro_f1': '0.346', 'macro_auc': '0.874', 'micro_f1': '0.426', 'micro_auc': '0.892'}
#
#
# aplha:  0.877
# {'macro_f1': '0.345', 'macro_auc': '0.873', 'micro_f1': '0.425', 'micro_auc': '0.891'}
#
#
# aplha:  0.878
# {'macro_f1': '0.345', 'macro_auc': '0.873', 'micro_f1': '0.425', 'micro_auc': '0.891'}
#
#
# aplha:  0.879
# {'macro_f1': '0.345', 'macro_auc': '0.873', 'micro_f1': '0.425', 'micro_auc': '0.891'}
#
#
# aplha:  0.88
# {'macro_f1': '0.344', 'macro_auc': '0.873', 'micro_f1': '0.424', 'micro_auc': '0.891'}
#
#
# aplha:  0.881
# {'macro_f1': '0.344', 'macro_auc': '0.872', 'micro_f1': '0.423', 'micro_auc': '0.890'}
# aplha:  0.882
# {'macro_f1': '0.344', 'macro_auc': '0.872', 'micro_f1': '0.423', 'micro_auc': '0.890'}
#
#
# aplha:  0.883
# {'macro_f1': '0.344', 'macro_auc': '0.872', 'micro_f1': '0.422', 'micro_auc': '0.890'}
#
#
# aplha:  0.884
# {'macro_f1': '0.344', 'macro_auc': '0.872', 'micro_f1': '0.422', 'micro_auc': '0.890'}
#
#
# aplha:  0.885
# {'macro_f1': '0.343', 'macro_auc': '0.871', 'micro_f1': '0.422', 'micro_auc': '0.889'}
#
#
# aplha:  0.886
# {'macro_f1': '0.343', 'macro_auc': '0.871', 'micro_f1': '0.421', 'micro_auc': '0.889'}
#
#
# aplha:  0.887
# {'macro_f1': '0.343', 'macro_auc': '0.871', 'micro_f1': '0.421', 'micro_auc': '0.889'}
#
#
# aplha:  0.888
# {'macro_f1': '0.342', 'macro_auc': '0.870', 'micro_f1': '0.420', 'micro_auc': '0.889'}
#
#
# aplha:  0.889
# {'macro_f1': '0.342', 'macro_auc': '0.870', 'micro_f1': '0.420', 'micro_auc': '0.888'}
#
#
# aplha:  0.89
# {'macro_f1': '0.342', 'macro_auc': '0.870', 'micro_f1': '0.419', 'micro_auc': '0.888'}
#
#
# aplha:  0.891
# {'macro_f1': '0.341', 'macro_auc': '0.870', 'micro_f1': '0.419', 'micro_auc': '0.888'}
#
#
# aplha:  0.892
# {'macro_f1': '0.341', 'macro_auc': '0.869', 'micro_f1': '0.419', 'micro_auc': '0.887'}
#
#
# aplha:  0.893
# {'macro_f1': '0.341', 'macro_auc': '0.869', 'micro_f1': '0.419', 'micro_auc': '0.887'}
#
#
# aplha:  0.894
# {'macro_f1': '0.341', 'macro_auc': '0.869', 'micro_f1': '0.418', 'micro_auc': '0.887'}
#
#
# aplha:  0.895
# {'macro_f1': '0.340', 'macro_auc': '0.868', 'micro_f1': '0.418', 'micro_auc': '0.886'}
#
#
# aplha:  0.896
# {'macro_f1': '0.340', 'macro_auc': '0.868', 'micro_f1': '0.417', 'micro_auc': '0.886'}
#
#
# aplha:  0.897
# {'macro_f1': '0.340', 'macro_auc': '0.868', 'micro_f1': '0.417', 'micro_auc': '0.886'}
#
#
# aplha:  0.898
# {'macro_f1': '0.338', 'macro_auc': '0.867', 'micro_f1': '0.416', 'micro_auc': '0.886'}
#
#
# aplha:  0.899
# {'macro_f1': '0.338', 'macro_auc': '0.867', 'micro_f1': '0.416', 'micro_auc': '0.885'}
#
#
# aplha:  0.9
# {'macro_f1': '0.338', 'macro_auc': '0.867', 'micro_f1': '0.415', 'micro_auc': '0.885'}
#
#
# aplha:  0.901
# {'macro_f1': '0.338', 'macro_auc': '0.866', 'micro_f1': '0.414', 'micro_auc': '0.885'}
#
#
# aplha:  0.902
# {'macro_f1': '0.337', 'macro_auc': '0.866', 'micro_f1': '0.414', 'micro_auc': '0.884'}
#
#
# aplha:  0.903
# {'macro_f1': '0.337', 'macro_auc': '0.866', 'micro_f1': '0.414', 'micro_auc': '0.884'}
#
#
# aplha:  0.904
# {'macro_f1': '0.336', 'macro_auc': '0.865', 'micro_f1': '0.413', 'micro_auc': '0.884'}
#
#
# aplha:  0.905
# {'macro_f1': '0.336', 'macro_auc': '0.865', 'micro_f1': '0.412', 'micro_auc': '0.883'}
#
#
# aplha:  0.906
# {'macro_f1': '0.336', 'macro_auc': '0.865', 'micro_f1': '0.412', 'micro_auc': '0.883'}
#
#
# aplha:  0.907
# {'macro_f1': '0.336', 'macro_auc': '0.864', 'micro_f1': '0.412', 'micro_auc': '0.883'}
#
#
# aplha:  0.908
# {'macro_f1': '0.336', 'macro_auc': '0.864', 'micro_f1': '0.412', 'micro_auc': '0.882'}
#
#
# aplha:  0.909
# {'macro_f1': '0.336', 'macro_auc': '0.863', 'micro_f1': '0.412', 'micro_auc': '0.882'}
#
#
# aplha:  0.91
# {'macro_f1': '0.336', 'macro_auc': '0.863', 'micro_f1': '0.412', 'micro_auc': '0.882'}
#
#
# aplha:  0.911
# {'macro_f1': '0.336', 'macro_auc': '0.863', 'micro_f1': '0.412', 'micro_auc': '0.881'}
#
#
# aplha:  0.912
# {'macro_f1': '0.334', 'macro_auc': '0.862', 'micro_f1': '0.411', 'micro_auc': '0.881'}
#
#
# aplha:  0.913
# {'macro_f1': '0.334', 'macro_auc': '0.862', 'micro_f1': '0.411', 'micro_auc': '0.881'}
#
#
# aplha:  0.914
# {'macro_f1': '0.334', 'macro_auc': '0.862', 'micro_f1': '0.411', 'micro_auc': '0.880'}
#
#
# aplha:  0.915
# {'macro_f1': '0.333', 'macro_auc': '0.861', 'micro_f1': '0.410', 'micro_auc': '0.880'}
#
#
# aplha:  0.916
# {'macro_f1': '0.332', 'macro_auc': '0.861', 'micro_f1': '0.410', 'micro_auc': '0.880'}
#
#
# aplha:  0.917
# {'macro_f1': '0.332', 'macro_auc': '0.860', 'micro_f1': '0.408', 'micro_auc': '0.879'}
#
#
# aplha:  0.918
# {'macro_f1': '0.332', 'macro_auc': '0.860', 'micro_f1': '0.408', 'micro_auc': '0.879'}
#
#
# aplha:  0.919
# {'macro_f1': '0.332', 'macro_auc': '0.860', 'micro_f1': '0.408', 'micro_auc': '0.879'}
#
#
# aplha:  0.92
# {'macro_f1': '0.331', 'macro_auc': '0.859', 'micro_f1': '0.407', 'micro_auc': '0.878'}
#
#
# aplha:  0.921
# {'macro_f1': '0.331', 'macro_auc': '0.859', 'micro_f1': '0.407', 'micro_auc': '0.878'}
#
#
# aplha:  0.922
# {'macro_f1': '0.331', 'macro_auc': '0.858', 'micro_f1': '0.406', 'micro_auc': '0.878'}
#
#
# aplha:  0.923
# {'macro_f1': '0.331', 'macro_auc': '0.858', 'micro_f1': '0.406', 'micro_auc': '0.877'}
#
#
# aplha:  0.924
# {'macro_f1': '0.331', 'macro_auc': '0.858', 'micro_f1': '0.406', 'micro_auc': '0.877'}
#
#
# aplha:  0.925
# {'macro_f1': '0.330', 'macro_auc': '0.857', 'micro_f1': '0.405', 'micro_auc': '0.877'}
#
#
# aplha:  0.926
# {'macro_f1': '0.330', 'macro_auc': '0.857', 'micro_f1': '0.405', 'micro_auc': '0.876'}
#
#
# aplha:  0.927
# {'macro_f1': '0.330', 'macro_auc': '0.856', 'micro_f1': '0.405', 'micro_auc': '0.876'}
#
#
# aplha:  0.928
# {'macro_f1': '0.329', 'macro_auc': '0.856', 'micro_f1': '0.404', 'micro_auc': '0.875'}
#
#
# aplha:  0.929
# {'macro_f1': '0.329', 'macro_auc': '0.855', 'micro_f1': '0.404', 'micro_auc': '0.875'}
#
#
# aplha:  0.93
# {'macro_f1': '0.328', 'macro_auc': '0.855', 'micro_f1': '0.404', 'micro_auc': '0.875'}
#
#
# aplha:  0.931
# {'macro_f1': '0.327', 'macro_auc': '0.854', 'micro_f1': '0.403', 'micro_auc': '0.874'}
#
#
# aplha:  0.932
# {'macro_f1': '0.327', 'macro_auc': '0.854', 'micro_f1': '0.403', 'micro_auc': '0.874'}
#
#
# aplha:  0.933
# {'macro_f1': '0.327', 'macro_auc': '0.853', 'micro_f1': '0.403', 'micro_auc': '0.873'}
#
#
# aplha:  0.934
# {'macro_f1': '0.328', 'macro_auc': '0.853', 'micro_f1': '0.403', 'micro_auc': '0.873'}
#
#
# aplha:  0.935
# {'macro_f1': '0.328', 'macro_auc': '0.852', 'micro_f1': '0.403', 'micro_auc': '0.873'}
#
#
# aplha:  0.936
# {'macro_f1': '0.328', 'macro_auc': '0.852', 'micro_f1': '0.403', 'micro_auc': '0.872'}
#
#
# aplha:  0.937
# {'macro_f1': '0.328', 'macro_auc': '0.851', 'micro_f1': '0.403', 'micro_auc': '0.872'}
#
#
# aplha:  0.9380000000000001
# {'macro_f1': '0.327', 'macro_auc': '0.851', 'micro_f1': '0.402', 'micro_auc': '0.871'}
#
#
# aplha:  0.9390000000000001
# {'macro_f1': '0.326', 'macro_auc': '0.850', 'micro_f1': '0.402', 'micro_auc': '0.871'}
#
#
# aplha:  0.9400000000000001
# {'macro_f1': '0.326', 'macro_auc': '0.850', 'micro_f1': '0.401', 'micro_auc': '0.871'}
#
#
# aplha:  0.9410000000000001
# {'macro_f1': '0.326', 'macro_auc': '0.849', 'micro_f1': '0.401', 'micro_auc': '0.870'}
#
#
# aplha:  0.9420000000000001
# {'macro_f1': '0.326', 'macro_auc': '0.849', 'micro_f1': '0.401', 'micro_auc': '0.870'}
#
#
# aplha:  0.9430000000000001
# {'macro_f1': '0.326', 'macro_auc': '0.848', 'micro_f1': '0.401', 'micro_auc': '0.869'}
#
#
# aplha:  0.9440000000000001
# {'macro_f1': '0.326', 'macro_auc': '0.848', 'micro_f1': '0.400', 'micro_auc': '0.869'}
#
#
# aplha:  0.9450000000000001
# {'macro_f1': '0.325', 'macro_auc': '0.847', 'micro_f1': '0.400', 'micro_auc': '0.868'}
#
#
# aplha:  0.9460000000000001
# {'macro_f1': '0.325', 'macro_auc': '0.847', 'micro_f1': '0.400', 'micro_auc': '0.868'}
#
#
# aplha:  0.9470000000000001
# {'macro_f1': '0.325', 'macro_auc': '0.846', 'micro_f1': '0.399', 'micro_auc': '0.867'}
#
#
# aplha:  0.9480000000000001
# {'macro_f1': '0.324', 'macro_auc': '0.846', 'micro_f1': '0.399', 'micro_auc': '0.867'}
#
#
# aplha:  0.9490000000000001
# {'macro_f1': '0.324', 'macro_auc': '0.845', 'micro_f1': '0.398', 'micro_auc': '0.867'}
#
#
# aplha:  0.9500000000000001
# {'macro_f1': '0.324', 'macro_auc': '0.844', 'micro_f1': '0.398', 'micro_auc': '0.866'}
#
#
# aplha:  0.9510000000000001
# {'macro_f1': '0.323', 'macro_auc': '0.844', 'micro_f1': '0.398', 'micro_auc': '0.866'}
#
#
# aplha:  0.9520000000000001
# {'macro_f1': '0.322', 'macro_auc': '0.843', 'micro_f1': '0.397', 'micro_auc': '0.865'}
#
#
# aplha:  0.9530000000000001
# {'macro_f1': '0.322', 'macro_auc': '0.843', 'micro_f1': '0.397', 'micro_auc': '0.865'}
#
#
# aplha:  0.9540000000000001
# {'macro_f1': '0.322', 'macro_auc': '0.842', 'micro_f1': '0.397', 'micro_auc': '0.864'}
#
#
# aplha:  0.9550000000000001
# {'macro_f1': '0.322', 'macro_auc': '0.841', 'micro_f1': '0.397', 'micro_auc': '0.864'}
#
#
# aplha:  0.9560000000000001
# {'macro_f1': '0.322', 'macro_auc': '0.841', 'micro_f1': '0.396', 'micro_auc': '0.863'}
#
#
# aplha:  0.9570000000000001
# {'macro_f1': '0.322', 'macro_auc': '0.840', 'micro_f1': '0.396', 'micro_auc': '0.863'}
#
#
# aplha:  0.9580000000000001
# {'macro_f1': '0.321', 'macro_auc': '0.839', 'micro_f1': '0.395', 'micro_auc': '0.862'}
#
#
# aplha:  0.9590000000000001
# {'macro_f1': '0.321', 'macro_auc': '0.839', 'micro_f1': '0.395', 'micro_auc': '0.862'}
# aplha:  0.96
# {'macro_f1': '0.320', 'macro_auc': '0.838', 'micro_f1': '0.394', 'micro_auc': '0.861'}
#
#
# aplha:  0.961
# {'macro_f1': '0.320', 'macro_auc': '0.837', 'micro_f1': '0.394', 'micro_auc': '0.861'}
#
#
# aplha:  0.962
# {'macro_f1': '0.320', 'macro_auc': '0.837', 'micro_f1': '0.393', 'micro_auc': '0.860'}
#
#
# aplha:  0.963
# {'macro_f1': '0.320', 'macro_auc': '0.836', 'micro_f1': '0.393', 'micro_auc': '0.860'}
#
#
# aplha:  0.964
# {'macro_f1': '0.319', 'macro_auc': '0.835', 'micro_f1': '0.393', 'micro_auc': '0.859'}
#
#
# aplha:  0.965
# {'macro_f1': '0.319', 'macro_auc': '0.835', 'micro_f1': '0.392', 'micro_auc': '0.859'}
#
#
# aplha:  0.966
# {'macro_f1': '0.319', 'macro_auc': '0.834', 'micro_f1': '0.391', 'micro_auc': '0.858'}
#
#
# aplha:  0.967
# {'macro_f1': '0.318', 'macro_auc': '0.833', 'micro_f1': '0.391', 'micro_auc': '0.857'}
#
#
# aplha:  0.968
# {'macro_f1': '0.318', 'macro_auc': '0.832', 'micro_f1': '0.391', 'micro_auc': '0.857'}
#
#
# aplha:  0.969
# {'macro_f1': '0.318', 'macro_auc': '0.831', 'micro_f1': '0.391', 'micro_auc': '0.856'}
#
#
# aplha:  0.97
# {'macro_f1': '0.317', 'macro_auc': '0.830', 'micro_f1': '0.390', 'micro_auc': '0.856'}
#
#
# aplha:  0.971
# {'macro_f1': '0.317', 'macro_auc': '0.830', 'micro_f1': '0.390', 'micro_auc': '0.855'}
#
#
# aplha:  0.972
# {'macro_f1': '0.317', 'macro_auc': '0.829', 'micro_f1': '0.390', 'micro_auc': '0.855'}
#
#
# aplha:  0.973
# {'macro_f1': '0.316', 'macro_auc': '0.828', 'micro_f1': '0.389', 'micro_auc': '0.854'}
#
#
# aplha:  0.974
# {'macro_f1': '0.315', 'macro_auc': '0.827', 'micro_f1': '0.389', 'micro_auc': '0.853'}
#
#
# aplha:  0.975
# {'macro_f1': '0.315', 'macro_auc': '0.826', 'micro_f1': '0.388', 'micro_auc': '0.853'}
#
#
# aplha:  0.976
# {'macro_f1': '0.314', 'macro_auc': '0.825', 'micro_f1': '0.387', 'micro_auc': '0.852'}
#
#
# aplha:  0.977
# {'macro_f1': '0.313', 'macro_auc': '0.824', 'micro_f1': '0.386', 'micro_auc': '0.852'}
#
#
# aplha:  0.978
# {'macro_f1': '0.313', 'macro_auc': '0.823', 'micro_f1': '0.386', 'micro_auc': '0.851'}
#
#
# aplha:  0.979
# {'macro_f1': '0.313', 'macro_auc': '0.822', 'micro_f1': '0.386', 'micro_auc': '0.850'}
#
#
# aplha:  0.98
# {'macro_f1': '0.313', 'macro_auc': '0.821', 'micro_f1': '0.386', 'micro_auc': '0.850'}
#
#
# aplha:  0.981
# {'macro_f1': '0.313', 'macro_auc': '0.820', 'micro_f1': '0.386', 'micro_auc': '0.849'}
#
#
# aplha:  0.982
# {'macro_f1': '0.312', 'macro_auc': '0.819', 'micro_f1': '0.385', 'micro_auc': '0.848'}
#
#
# aplha:  0.983
# {'macro_f1': '0.312', 'macro_auc': '0.818', 'micro_f1': '0.385', 'micro_auc': '0.848'}
#
#
# aplha:  0.984
# {'macro_f1': '0.312', 'macro_auc': '0.817', 'micro_f1': '0.385', 'micro_auc': '0.847'}
#
#
# aplha:  0.985
# {'macro_f1': '0.312', 'macro_auc': '0.815', 'micro_f1': '0.384', 'micro_auc': '0.847'}
#
#
# aplha:  0.986
# {'macro_f1': '0.311', 'macro_auc': '0.814', 'micro_f1': '0.384', 'micro_auc': '0.846'}
#
#
# aplha:  0.987
# {'macro_f1': '0.310', 'macro_auc': '0.813', 'micro_f1': '0.383', 'micro_auc': '0.845'}
#
#
# aplha:  0.988
# {'macro_f1': '0.308', 'macro_auc': '0.811', 'micro_f1': '0.383', 'micro_auc': '0.845'}
#
#
# aplha:  0.989
# {'macro_f1': '0.309', 'macro_auc': '0.810', 'micro_f1': '0.383', 'micro_auc': '0.844'}
#
#
# aplha:  0.99
# {'macro_f1': '0.309', 'macro_auc': '0.809', 'micro_f1': '0.383', 'micro_auc': '0.843'}
#
#
# aplha:  0.991
# {'macro_f1': '0.308', 'macro_auc': '0.807', 'micro_f1': '0.383', 'micro_auc': '0.842'}
#
#
# aplha:  0.992
# {'macro_f1': '0.308', 'macro_auc': '0.806', 'micro_f1': '0.382', 'micro_auc': '0.842'}
#
#
# aplha:  0.993
# {'macro_f1': '0.308', 'macro_auc': '0.804', 'micro_f1': '0.382', 'micro_auc': '0.841'}
#
#
# aplha:  0.994
# {'macro_f1': '0.308', 'macro_auc': '0.802', 'micro_f1': '0.381', 'micro_auc': '0.840'}
#
#
# aplha:  0.995
# {'macro_f1': '0.308', 'macro_auc': '0.801', 'micro_f1': '0.382', 'micro_auc': '0.840'}
#
#
# aplha:  0.996
# {'macro_f1': '0.308', 'macro_auc': '0.799', 'micro_f1': '0.381', 'micro_auc': '0.839'}
#
#
# aplha:  0.997
# {'macro_f1': '0.308', 'macro_auc': '0.797', 'micro_f1': '0.381', 'micro_auc': '0.838'}
#
#
# aplha:  0.998
# {'macro_f1': '0.307', 'macro_auc': '0.795', 'micro_f1': '0.380', 'micro_auc': '0.837'}
#
#
# aplha:  0.999
# {'macro_f1': '0.307', 'macro_auc': '0.792', 'micro_f1': '0.380', 'micro_auc': '0.837'}

# %%
alphas = np.arange(0, 1, 0.001)
mi_auc = np.array(mi_auc)
ma_auc = np.array(ma_auc)
mi_f1 = np.array(mi_f1)
ma_f1 = np.array(ma_f1)

# %%
y = mi_auc
plt.plot(alphas, y)
ymax = max(y)
xpos = np.where(y == ymax)
xmax = alphas[xpos]

plt.grid()
plt.show()

print('Max value: ', ymax, ', at alpha = ', xmax)
# Out:
# Max value:  0.9300371809374303 , at alpha =  [0.254]

# %%
summ = np.add(mi_auc, ma_auc)
summ = np.add(summ, mi_f1)
summ = np.add(summ, ma_f1)

# %%
pos = np.where(summ == max(summ))
print('pos:', pos)
print('alpha:', alphas[pos])
# Out:
# pos: (array([164]),)
# alpha: [0.164]

# %%
print('micro_auc:', mi_auc[pos])
print('macro_auc:', ma_auc[pos])
print('micro-f1:', mi_f1[pos])
print('macro-f1:', ma_f1[pos])
# Out:
# micro_auc: [0.92964681]
# macro_auc: [0.90296107]
# micro-f1: [0.69139494]
# macro-f1: [0.6635349]

# %% [markdown]
# # Training Structured Data on neural network

# %%
train_df = pd.read_csv('../../Structured/train_final.csv')
train_dataset = train_df.to_dict('records')

test_df = pd.read_csv('../../Structured/test_final.csv')
test_dataset = test_df.to_dict('records')

dev_df = pd.read_csv('../../Structured/dev_final.csv')
dev_dataset = dev_df.to_dict('records')

# %%
def generate_dataset(dataset):
# convert df icd9_codes column into one hot vector
    for row in dataset:
        labels = [0] * 50
        codes = list(row['ICD9_CODE'].split(";"))
        for i in range(len(codes)):
            labels[icd9.index(codes[i])] = 1
        row['ICD9_CODE'] = labels

        # get list of features (lab events item ids) 
        keys = dataset[0].keys()
        keys = list(keys)
        keys.remove('SUBJECT_ID')
        keys.remove('HADM_ID')
        keys.remove('ICD9_CODE')

    # Create dataset from df feature values
    X = []
    y = []
    for row in dataset:
        x = []
        for key in keys:
            x.append(row[key])
        X.append(x)
        y.append(row['ICD9_CODE'])
    return X, y

# %%
X_train, y_train = generate_dataset(train_dataset)
X_test, y_test = generate_dataset(test_dataset)
X_train = np.array(X_train)
y_test = np.array(y_test)
y_train = np.array(y_train)
X_test = np.array(X_test)

# %%
X_train = torch.from_numpy(X_train)
y_train = torch.from_numpy(y_train)
X_test = torch.from_numpy(X_test)
y_test = torch.from_numpy(y_test)

X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)

# %%
class StructuredModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear_layer1 = nn.Linear(in_features = 1530, out_features = 1024)
        self.linear_layer2 = nn.Linear(in_features = 1024, out_features = 512)
        self.linear_layer3 = nn.Linear(in_features = 512, out_features = 256)
        self.linear_layer4 = nn.Linear(in_features = 256, out_features = 128)
        self.linear_layer5 = nn.Linear(in_features = 128, out_features = 64)
        self.linear_layer6 = nn.Linear(in_features = 64, out_features = 50)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        op1 = self.linear_layer1(x)
        op1a = torch.tanh(op1)
        op2 = self.linear_layer2(op1a)
        op2a = torch.tanh(op2)
        op3 = self.linear_layer3(op2a)
        op3a = torch.tanh(op3)        
        op4 = self.linear_layer4(op3a)
        op4a = torch.tanh(op4)
        op5 = self.linear_layer5(op4a)
        op5a = torch.tanh(op5)
        op6 = self.linear_layer6(op5a)
        output = torch.sigmoid(op6)
        return output

# %%
smodel = StructuredModel()
smodel.to(device)
    
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params = smodel.parameters(), lr = 0.001)

epochs = 500

for epoch in range(epochs):
    smodel.train()
    y_pred = smodel(X_train.float())
    loss = loss_fn(y_pred, y_train.float())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    smodel.eval()
    with torch.inference_mode():
        y_pred_test = smodel(X_test.float())
        loss_test = loss_fn(y_pred_test, y_test.float())
        
    if epoch %50==0:
        print(f"Epoch: {epoch} | Training Loss: {loss} | Test Loss: {loss_test}")
        scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test.cpu(), y_pred_test.cpu(), True)
        keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
        print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
        print()

# %%
struct_input = y_pred_test

# %%
struct_input = struct_input.cpu().numpy()
struct_input

# %%
mi_auc = []
ma_auc = []
mi_f1 = []
ma_f1 = []

for alpha in np.arange(0.0, 1.0, 0.001):
    final_output = struct_input * alpha + unstruct_input * (1 - alpha)
    scores = calculate_eval_metrics(test_scores['hadm_ids'], y_test.cpu(), final_output, True)
    keys = ['micro_auc', 'macro_auc', 'micro_f1', 'macro_f1']
    print('aplha: ', alpha)
    print({k:"{:.3f}".format(v) for k,v in scores.items() if k in keys})
    mi_auc.append(scores['micro_auc'])
    ma_auc.append(scores['macro_auc'])
    mi_f1.append(scores['micro_f1'])
    ma_f1.append(scores['macro_f1'])
    print('\n')

# %%
alphas = np.arange(0, 1, 0.001)
mi_auc = np.array(mi_auc)
ma_auc = np.array(ma_auc)
mi_f1 = np.array(mi_f1)
ma_f1 = np.array(ma_f1)

# %%
y = mi_auc
plt.plot(alphas, y)
ymax = max(y)
xpos = np.where(y == ymax)
xmax = alphas[xpos]

plt.grid()
plt.show()

print('Max value: ', ymax, ', at alpha = ', xmax)

# %%
summ = np.add(mi_auc, ma_auc)
summ = np.add(summ, mi_f1)
summ = np.add(summ, ma_f1)

# %%
pos = np.where(summ == max(summ))
print('pos:', pos)
print('alpha:', alphas[pos])

# %%
print('micro_auc:', mi_auc[pos])
print('macro_auc:', ma_auc[pos])
print('micro-f1:', mi_f1[pos])
print('macro-f1:', ma_f1[pos])
